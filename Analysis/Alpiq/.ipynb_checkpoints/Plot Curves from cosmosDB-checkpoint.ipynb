# %%
import os
import sys
import itertools

import pydocumentdb.documents as documents
import pydocumentdb.document_client as document_client
import pydocumentdb.errors as errors

import pandas as pd;pd.options.display.max_rows = 999
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np

import view.config as cfg
import view.storage as st

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from IPython.core.display import HTML
from IPython.display import display

# %%
HOST = cfg.settings.host
MASTER_KEY = cfg.settings.master_key
DATABASE_ID = cfg.settings.database_id
COLLECTION_ID = cfg.settings.collection_id

# %% [markdown]
# #### 1. Fetch available resources

# %%
res_query = "select c.resourcename from c"
res_names = st.Reader(DATABASE_ID, COLLECTION_ID, res_query, cfg.settings)
res_names = np.unique([resource["resourcename"] for resource in res_names])

# %% [markdown]
# #### 2. Download Data from CosmosDB

# %%
data = {}
dividers = {}

for res_name in res_names:
    
    doc_query = "select * from c where c.resourcename = '{0}'".format(res_name)
    
    docs = st.Reader(DATABASE_ID, COLLECTION_ID, doc_query, cfg.settings)
    
    if not len(docs) == 0:
        df = pd.DataFrame([item for doc in docs for item in doc["data"]])
        data[res_name] = df
        
        dividers[res_name] = getattr(cfg.groups, docs[0]["apiname"])

# %% [markdown]
# #### 3. Basics Statistics

# %%
def GetDescription( df, dividers, res_names, index_names ):
	description = GetDescribe( df, dividers, res_names )
	description_df = {}
	for key, value in description.iteritems():
		description_df[key] = GetSingletonStatistic(description[key])
	
	description_df = pd.concat(description_df)
	description_df.index.names = index_names
	return description_df

def GetStatistics( df, dividers, res_names ):
	description = {}
	
	for res_name in res_names:
	
		if not data[res_name].empty:
			if (dividers[res_name] != None 
				and any(dividers[res_name] in s for s in data[res_name].columns.values)):
				groups = data[res_name].groupby([dividers[res_name]])
				description[res_name] = groups.describe()
				description[res_name] = GetSingletonStatistic(description[res_name])
			else:
				description[res_name] = data[res_name].describe().T
				description[res_name].columns = pd.MultiIndex.from_tuples([(res_name, c) for c in description[res_name].columns])
				description[res_name] = GetSingletonStatistic(description[res_name])
	
	return description


def GetSingletonStatistic( description ):
	description = description.stack(0).reset_index(1)
	description = description.rename(index=str, columns={"level_1": "Value_Type"})
	index = pd.MultiIndex.from_tuples(GetSubResourceIndexs( description ))
	description = pd.DataFrame(description.values,index,description.columns);
	description= description.drop('Value_Type', axis=1)
	return description

def GetSubResourceIndexs( description ):
	index =[]
	if (type([description.Value_Type[i] for i in description.index][0])  is pd.core.series.Series) :
		index = pd.MultiIndex.from_tuples([(i,s) for i in description.index for s in description.Value_Type[i]])
	else:
		index = pd.MultiIndex.from_tuples([(i,description.Value_Type[i]) for i in description.index])
	
	return index.unique()



def GetDescribe( df, dividers, res_names ):
	description = {}
	
	for res_name in res_names:
	
		if not data[res_name].empty:
			if (dividers[res_name] != None 
				and any(dividers[res_name] in s for s in data[res_name].columns.values)):
				groups = data[res_name].groupby([dividers[res_name]])
				description[res_name] = groups.describe()
			else:
				description[res_name] = data[res_name].describe().T
				description[res_name].columns = pd.MultiIndex.from_tuples([(res_name, c) for c in description[res_name].columns])
	
	return description

index_names = ["Resource Type","Resource Subtype","Value Type"]
df = GetDescription2( data, dividers, res_names, index_names )
df
# Out:
#                                                                                                                                       25%  \
# Resource Type                              Resource Subtype                       Value Type
# accepted_offers                            AFRR                                   value                                               614
#                                            FCR                                    value                                               621
#                                            MFRR                                   value                                           2499.75
#                                            RR                                     value                                             11834
# actual_generations_per_production_type     BIOMASS                                value                                               194
#                                            FOSSIL_GAS                             value                                            1638.5
#                                            FOSSIL_HARD_COAL                       value                                            398.25
#                                            FOSSIL_OIL                             value                                               255
#                                            HYDRO_PUMPED_STORAGE                   value                                              -369
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        value                                              4998
#                                            HYDRO_WATER_RESERVOIR                  value                                           1174.75
#                                            NUCLEAR                                value                                             44119
#                                            SOLAR                                  value                                              21.5
#                                            TOTAL                                  value                                             58186
#                                            WASTE                                  value                                               195
#                                            WIND_ONSHORE                           value                                           1127.25
# actual_generations_per_unit                value                                  actual_generations_per_unit                         112
# additional_national_alignment_coefficients value                                  additional_national_alignment_coefficients     0.952887
# capacities_per_production_unit             FOSSIL_GAS                             installed_capacity                               403.75
#                                                                                   voltage_level_connection                            225
#                                            FOSSIL_HARD_COAL                       installed_capacity                                  250
#                                                                                   voltage_level_connection                            225
#                                            FOSSIL_OIL                             installed_capacity                                  128
#                                                                                   voltage_level_connection                            225
#                                            HYDRO_PUMPED_STORAGE                   installed_capacity                              549.325
#                                                                                   voltage_level_connection                            400
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        installed_capacity                                125.1
#                                                                                   voltage_level_connection                            225
#                                            HYDRO_WATER_RESERVOIR                  installed_capacity                               135.65
#                                                                                   voltage_level_connection                            225
#                                            MARINE                                 installed_capacity                                  240
#                                                                                   voltage_level_connection                            225
#                                            NUCLEAR                                installed_capacity                                  910
#                                                                                   voltage_level_connection                            400
#                                            OTHER                                  installed_capacity                                   62
#                                                                                   voltage_level_connection                            225
# forecasts                                  D-1                                    load_factor                                       37.75
#                                                                                   value                                             10561
#                                            ID                                     load_factor                                           0
#                                                                                   value                                              2619
# generation_mix_15min_time_scale            BIOENERGY                              value                                               735
#                                            EXCHANGE                               value                                             -8619
#                                            FOSSIL_GAS                             value                                           4839.75
#                                            FOSSIL_HARD_COAL                       value                                               519
#                                            FOSSIL_OIL                             value                                               175
#                                            HYDRO                                  value                                              5031
#                                            NUCLEAR                                value                                             45129
#                                            PUMPING                                value                                                 0
#                                            SOLAR                                  value                                                 0
#                                            WIND                                   value                                           1497.75
# generation_unavailabilities                FORCED_UNAVAILABILITY                  value                                                 0
#                                            PLANNED_MAINTENANCE                    value                                                 0
# imbalance_data                             imbalance                              imbalance_data                                 -222.505
#                                            negative_imbalance_settlement_price    imbalance_data                                    29.18
#                                            positive_imbalance_settlement_price    imbalance_data                                    22.22
# insufficients_offers                       DOWNGRADED                             direction                                           NaN
#                                                                                   end_date                                            NaN
#                                                                                   nature                                              NaN
#                                                                                   start_date                                          NaN
#                                                                                   updated_date                                        NaN
#                                            WARNING                                direction                                           NaN
#                                                                                   end_date                                            NaN
#                                                                                   nature                                              NaN
#                                                                                   start_date                                          NaN
#                                                                                   updated_date                                        NaN
# lead_times                                 fat_maximum_price                      lead_times                                            0
#                                            fat_minimum_price                      lead_times                                            0
#                                            mindp_maximum_price                    lead_times                                            0
#                                            mindp_minimum_price                    lead_times                                            0
# national_alignment_coefficients            value                                  national_alignment_coefficients                0.946464
# national_profiling_imbalances              value                                  national_profiling_imbalances                  -1228.13
# national_reference_load_curves             value                                  national_reference_load_curves                    32872
# peak_daily_margins                         EVENING                                available_value                                  6450.2
#                                                                                   required_value                                     2675
#                                            MORNING                                available_value                                    5721
#                                                                                   required_value                                     2600
# prices                                     downward_marginal_price                prices                                             4.56
#                                            downward_marginal_price_as             prices                                                0
#                                            downward_marginal_price_margin         prices                                                0
#                                            downward_weighted_average_price        prices                                            23.54
#                                            downward_weighted_average_price_as     prices                                            10.66
#                                            downward_weighted_average_price_margin prices                                           28.845
#                                            downward_weighted_average_price_mfrr   prices                                             25.7
#                                            downward_weighted_average_price_rr     prices                                          25.8175
#                                            upward_marginal_price                  prices                                                0
#                                            upward_marginal_price_as               prices                                                0
#                                            upward_marginal_price_margin           prices                                                0
#                                            upward_weighted_average_price          prices                                            24.94
#                                            upward_weighted_average_price_as       prices                                            28.79
#                                            upward_weighted_average_price_margin   prices                                            28.92
#                                            upward_weighted_average_price_mfrr     prices                                            30.13
#                                            upward_weighted_average_price_rr       prices                                            29.97
# procured_reserves                          AFRR                                   price                                              9.16
#                                                                                   value                                               600
#                                            FCR                                    price                                              8.84
#                                                                                   value                                               571
#                                            MFRR                                   price                                              0.74
#                                                                                   value                                              1067
#                                            RR                                     price                                              0.62
#                                                                                   value                                               313
# transmission_network_unavailabilities      FORCED_UNAVAILABILITY                  value                                              1100
#                                                                                   version                                               3
#                                            PLANNED_MAINTENANCE                    value                                              1500
#                                                                                   version                                               7
# tso_offers                                 NG                                     downward_volume                                       0
#                                                                                   maximum_downward_price                          41.0525
#                                                                                   maximum_upward_price                             100.65
#                                                                                   minimum_downward_price                            28.68
#                                                                                   minimum_upward_price                                 82
#                                                                                   upward_volume                                         0
#                                            REE                                    downward_volume                                       0
#                                                                                   maximum_downward_price                             0.05
#                                                                                   maximum_upward_price                                 62
#                                                                                   minimum_downward_price                                0
#                                                                                   minimum_upward_price                                 60
#                                                                                   upward_volume                                         0
#                                            RTE                                    downward_volume                                       0
#                                                                                   maximum_downward_price                               23
#                                                                                   maximum_upward_price                               53.7
#                                                                                   minimum_downward_price                               21
#                                                                                   minimum_upward_price                                 51
#                                                                                   upward_volume                                         0
# water_reserves                             value                                  water_reserves                              1.31130e+06
#
#                                                                                                                                       50%  \
# Resource Type                              Resource Subtype                       Value Type
# accepted_offers                            AFRR                                   value                                               685
#                                            FCR                                    value                                               663
#                                            MFRR                                   value                                              4676
#                                            RR                                     value                                             14243
# actual_generations_per_production_type     BIOMASS                                value                                               209
#                                            FOSSIL_GAS                             value                                              2576
#                                            FOSSIL_HARD_COAL                       value                                              1408
#                                            FOSSIL_OIL                             value                                               273
#                                            HYDRO_PUMPED_STORAGE                   value                                                79
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        value                                            5676.5
#                                            HYDRO_WATER_RESERVOIR                  value                                              2084
#                                            NUCLEAR                                value                                             51215
#                                            SOLAR                                  value                                                43
#                                            TOTAL                                  value                                             69001
#                                            WASTE                                  value                                               275
#                                            WIND_ONSHORE                           value                                            1897.5
# actual_generations_per_unit                value                                  actual_generations_per_unit                         856
# additional_national_alignment_coefficients value                                  additional_national_alignment_coefficients     0.994014
# capacities_per_production_unit             FOSSIL_GAS                             installed_capacity                                  419
#                                                                                   voltage_level_connection                            225
#                                            FOSSIL_HARD_COAL                       installed_capacity                                  250
#                                                                                   voltage_level_connection                            225
#                                            FOSSIL_OIL                             installed_capacity                                183.5
#                                                                                   voltage_level_connection                            225
#                                            HYDRO_PUMPED_STORAGE                   installed_capacity                               775.15
#                                                                                   voltage_level_connection                            400
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        installed_capacity                                  150
#                                                                                   voltage_level_connection                            225
#                                            HYDRO_WATER_RESERVOIR                  installed_capacity                                189.2
#                                                                                   voltage_level_connection                            225
#                                            MARINE                                 installed_capacity                                  240
#                                                                                   voltage_level_connection                            225
#                                            NUCLEAR                                installed_capacity                                  915
#                                                                                   voltage_level_connection                            400
#                                            OTHER                                  installed_capacity                                   62
#                                                                                   voltage_level_connection                            225
# forecasts                                  D-1                                    load_factor                                          50
#                                                                                   value                                             12462
#                                            ID                                     load_factor                                           0
#                                                                                   value                                              3132
# generation_mix_15min_time_scale            BIOENERGY                              value                                               766
#                                            EXCHANGE                               value                                             -6000
#                                            FOSSIL_GAS                             value                                            6818.5
#                                            FOSSIL_HARD_COAL                       value                                            1196.5
#                                            FOSSIL_OIL                             value                                             275.5
#                                            HYDRO                                  value                                            6674.5
#                                            NUCLEAR                                value                                             47665
#                                            PUMPING                                value                                                 0
#                                            SOLAR                                  value                                                 0
#                                            WIND                                   value                                              2240
# generation_unavailabilities                FORCED_UNAVAILABILITY                  value                                                 0
#                                            PLANNED_MAINTENANCE                    value                                                 0
# imbalance_data                             imbalance                              imbalance_data                                   33.985
#                                            negative_imbalance_settlement_price    imbalance_data                                    38.13
#                                            positive_imbalance_settlement_price    imbalance_data                                    29.69
# insufficients_offers                       DOWNGRADED                             direction                                           NaN
#                                                                                   end_date                                            NaN
#                                                                                   nature                                              NaN
#                                                                                   start_date                                          NaN
#                                                                                   updated_date                                        NaN
#                                            WARNING                                direction                                           NaN
#                                                                                   end_date                                            NaN
#                                                                                   nature                                              NaN
#                                                                                   start_date                                          NaN
#                                                                                   updated_date                                        NaN
# lead_times                                 fat_maximum_price                      lead_times                                           13
#                                            fat_minimum_price                      lead_times                                           13
#                                            mindp_maximum_price                    lead_times                                            0
#                                            mindp_minimum_price                    lead_times                                            0
# national_alignment_coefficients            value                                  national_alignment_coefficients                0.989465
# national_profiling_imbalances              value                                  national_profiling_imbalances                  -137.031
# national_reference_load_curves             value                                  national_reference_load_curves                  38959.6
# peak_daily_margins                         EVENING                                available_value                                 8179.25
#                                                                                   required_value                                     2900
#                                            MORNING                                available_value                                  7399.5
#                                                                                   required_value                                     3500
# prices                                     downward_marginal_price                prices                                            21.74
#                                            downward_marginal_price_as             prices                                                0
#                                            downward_marginal_price_margin         prices                                                0
#                                            downward_weighted_average_price        prices                                            31.23
#                                            downward_weighted_average_price_as     prices                                            23.32
#                                            downward_weighted_average_price_margin prices                                            34.64
#                                            downward_weighted_average_price_mfrr   prices                                            31.29
#                                            downward_weighted_average_price_rr     prices                                            32.51
#                                            upward_marginal_price                  prices                                            35.09
#                                            upward_marginal_price_as               prices                                                0
#                                            upward_marginal_price_margin           prices                                                0
#                                            upward_weighted_average_price          prices                                            35.06
#                                            upward_weighted_average_price_as       prices                                            34.61
#                                            upward_weighted_average_price_margin   prices                                            34.85
#                                            upward_weighted_average_price_mfrr     prices                                             37.5
#                                            upward_weighted_average_price_rr       prices                                            36.66
# procured_reserves                          AFRR                                   price                                              9.18
#                                                                                   value                                               650
#                                            FCR                                    price                                              9.16
#                                                                                   value                                               574
#                                            MFRR                                   price                                              0.94
#                                                                                   value                                              1232
#                                            RR                                     price                                              0.77
#                                                                                   value                                               567
# transmission_network_unavailabilities      FORCED_UNAVAILABILITY                  value                                              1500
#                                                                                   version                                               5
#                                            PLANNED_MAINTENANCE                    value                                              1800
#                                                                                   version                                              15
# tso_offers                                 NG                                     downward_volume                                     500
#                                                                                   maximum_downward_price                            50.04
#                                                                                   maximum_upward_price                             230.88
#                                                                                   minimum_downward_price                               37
#                                                                                   minimum_upward_price                             200.54
#                                                                                   upward_volume                                       250
#                                            REE                                    downward_volume                                      50
#                                                                                   maximum_downward_price                             1.72
#                                                                                   maximum_upward_price                                 68
#                                                                                   minimum_downward_price                             0.46
#                                                                                   minimum_upward_price                             65.405
#                                                                                   upward_volume                                       500
#                                            RTE                                    downward_volume                                       0
#                                                                                   maximum_downward_price                            28.85
#                                                                                   maximum_upward_price                               83.5
#                                                                                   minimum_downward_price                             26.8
#                                                                                   minimum_upward_price                               63.6
#                                                                                   upward_volume                                       250
# water_reserves                             value                                  water_reserves                              2.06618e+06
#
#                                                                                                                                       75%  \
# Resource Type                              Resource Subtype                       Value Type
# accepted_offers                            AFRR                                   value                                               782
#                                            FCR                                    value                                               722
#                                            MFRR                                   value                                              7051
#                                            RR                                     value                                             17199
# actual_generations_per_production_type     BIOMASS                                value                                               221
#                                            FOSSIL_GAS                             value                                            4658.5
#                                            FOSSIL_HARD_COAL                       value                                           2461.75
#                                            FOSSIL_OIL                             value                                               291
#                                            HYDRO_PUMPED_STORAGE                   value                                               785
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        value                                              6274
#                                            HYDRO_WATER_RESERVOIR                  value                                           3353.75
#                                            NUCLEAR                                value                                           57443.8
#                                            SOLAR                                  value                                              1164
#                                            TOTAL                                  value                                           75998.5
#                                            WASTE                                  value                                               286
#                                            WIND_ONSHORE                           value                                            3514.5
# actual_generations_per_unit                value                                  actual_generations_per_unit                       932.5
# additional_national_alignment_coefficients value                                  additional_national_alignment_coefficients      1.03648
# capacities_per_production_unit             FOSSIL_GAS                             installed_capacity                               433.25
#                                                                                   voltage_level_connection                            225
#                                            FOSSIL_HARD_COAL                       installed_capacity                                  580
#                                                                                   voltage_level_connection                            225
#                                            FOSSIL_OIL                             installed_capacity                                  585
#                                                                                   voltage_level_connection                            400
#                                            HYDRO_PUMPED_STORAGE                   installed_capacity                                884.5
#                                                                                   voltage_level_connection                            400
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        installed_capacity                                177.5
#                                                                                   voltage_level_connection                            225
#                                            HYDRO_WATER_RESERVOIR                  installed_capacity                                358.5
#                                                                                   voltage_level_connection                            225
#                                            MARINE                                 installed_capacity                                  240
#                                                                                   voltage_level_connection                            225
#                                            NUCLEAR                                installed_capacity                                 1310
#                                                                                   voltage_level_connection                            400
#                                            OTHER                                  installed_capacity                                   62
#                                                                                   voltage_level_connection                            225
# forecasts                                  D-1                                    load_factor                                       70.25
#                                                                                   value                                           60381.5
#                                            ID                                     load_factor                                           0
#                                                                                   value                                              4090
# generation_mix_15min_time_scale            BIOENERGY                              value                                               788
#                                            EXCHANGE                               value                                          -2264.75
#                                            FOSSIL_GAS                             value                                              8062
#                                            FOSSIL_HARD_COAL                       value                                              1988
#                                            FOSSIL_OIL                             value                                               468
#                                            HYDRO                                  value                                            8611.5
#                                            NUCLEAR                                value                                             52819
#                                            PUMPING                                value                                                 0
#                                            SOLAR                                  value                                            1593.5
#                                            WIND                                   value                                              3972
# generation_unavailabilities                FORCED_UNAVAILABILITY                  value                                                 0
#                                            PLANNED_MAINTENANCE                    value                                                 0
# imbalance_data                             imbalance                              imbalance_data                                  297.605
#                                            negative_imbalance_settlement_price    imbalance_data                                    52.01
#                                            positive_imbalance_settlement_price    imbalance_data                                    40.23
# insufficients_offers                       DOWNGRADED                             direction                                           NaN
#                                                                                   end_date                                            NaN
#                                                                                   nature                                              NaN
#                                                                                   start_date                                          NaN
#                                                                                   updated_date                                        NaN
#                                            WARNING                                direction                                           NaN
#                                                                                   end_date                                            NaN
#                                                                                   nature                                              NaN
#                                                                                   start_date                                          NaN
#                                                                                   updated_date                                        NaN
# lead_times                                 fat_maximum_price                      lead_times                                           13
#                                            fat_minimum_price                      lead_times                                           18
#                                            mindp_maximum_price                    lead_times                                           15
#                                            mindp_minimum_price                    lead_times                                            0
# national_alignment_coefficients            value                                  national_alignment_coefficients                 1.03912
# national_profiling_imbalances              value                                  national_profiling_imbalances                   1300.05
# national_reference_load_curves             value                                  national_reference_load_curves                  47720.9
# peak_daily_margins                         EVENING                                available_value                                   10048
#                                                                                   required_value                                     3000
#                                            MORNING                                available_value                                  9629.5
#                                                                                   required_value                                     3800
# prices                                     downward_marginal_price                prices                                            31.53
#                                            downward_marginal_price_as             prices                                             21.2
#                                            downward_marginal_price_margin         prices                                                0
#                                            downward_weighted_average_price        prices                                            41.77
#                                            downward_weighted_average_price_as     prices                                             33.4
#                                            downward_weighted_average_price_margin prices                                            40.01
#                                            downward_weighted_average_price_mfrr   prices                                          37.9825
#                                            downward_weighted_average_price_rr     prices                                            38.92
#                                            upward_marginal_price                  prices                                          54.4925
#                                            upward_marginal_price_as               prices                                                0
#                                            upward_marginal_price_margin           prices                                                0
#                                            upward_weighted_average_price          prices                                            47.67
# ...
# actual_generations_per_production_type     BIOMASS                                value                                         NaN
#                                            FOSSIL_GAS                             value                                         NaN
#                                            FOSSIL_HARD_COAL                       value                                         NaN
#                                            FOSSIL_OIL                             value                                         NaN
#                                            HYDRO_PUMPED_STORAGE                   value                                         NaN
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        value                                         NaN
#                                            HYDRO_WATER_RESERVOIR                  value                                         NaN
#                                            NUCLEAR                                value                                         NaN
#                                            SOLAR                                  value                                         NaN
#                                            TOTAL                                  value                                         NaN
#                                            WASTE                                  value                                         NaN
#                                            WIND_ONSHORE                           value                                         NaN
# actual_generations_per_unit                value                                  actual_generations_per_unit                   NaN
# additional_national_alignment_coefficients value                                  additional_national_alignment_coefficients    NaN
# capacities_per_production_unit             FOSSIL_GAS                             installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            FOSSIL_HARD_COAL                       installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            FOSSIL_OIL                             installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            HYDRO_PUMPED_STORAGE                   installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            HYDRO_RUN_OF_RIVER_AND_POUNDAGE        installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            HYDRO_WATER_RESERVOIR                  installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            MARINE                                 installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            NUCLEAR                                installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
#                                            OTHER                                  installed_capacity                            NaN
#                                                                                   voltage_level_connection                      NaN
# forecasts                                  D-1                                    load_factor                                   NaN
#                                                                                   value                                         NaN
#                                            ID                                     load_factor                                   NaN
#                                                                                   value                                         NaN
# generation_mix_15min_time_scale            BIOENERGY                              value                                         NaN
#                                            EXCHANGE                               value                                         NaN
#                                            FOSSIL_GAS                             value                                         NaN
#                                            FOSSIL_HARD_COAL                       value                                         NaN
#                                            FOSSIL_OIL                             value                                         NaN
#                                            HYDRO                                  value                                         NaN
#                                            NUCLEAR                                value                                         NaN
#                                            PUMPING                                value                                         NaN
#                                            SOLAR                                  value                                         NaN
#                                            WIND                                   value                                         NaN
# generation_unavailabilities                FORCED_UNAVAILABILITY                  value                                         NaN
#                                            PLANNED_MAINTENANCE                    value                                         NaN
# imbalance_data                             imbalance                              imbalance_data                                NaN
#                                            negative_imbalance_settlement_price    imbalance_data                                NaN
#                                            positive_imbalance_settlement_price    imbalance_data                                NaN
# insufficients_offers                       DOWNGRADED                             direction                                       2
#                                                                                   end_date                                      159
#                                                                                   nature                                          2
#                                                                                   start_date                                    159
#                                                                                   updated_date                                  162
#                                            WARNING                                direction                                       2
#                                                                                   end_date                                       40
#                                                                                   nature                                          2
#                                                                                   start_date                                     40
#                                                                                   updated_date                                   39
# lead_times                                 fat_maximum_price                      lead_times                                    NaN
#                                            fat_minimum_price                      lead_times                                    NaN
#                                            mindp_maximum_price                    lead_times                                    NaN
#                                            mindp_minimum_price                    lead_times                                    NaN
# national_alignment_coefficients            value                                  national_alignment_coefficients               NaN
# national_profiling_imbalances              value                                  national_profiling_imbalances                 NaN
# national_reference_load_curves             value                                  national_reference_load_curves                NaN
# peak_daily_margins                         EVENING                                available_value                               NaN
#                                                                                   required_value                                NaN
#                                            MORNING                                available_value                               NaN
#                                                                                   required_value                                NaN
# prices                                     downward_marginal_price                prices                                        NaN
#                                            downward_marginal_price_as             prices                                        NaN
#                                            downward_marginal_price_margin         prices                                        NaN
#                                            downward_weighted_average_price        prices                                        NaN
#                                            downward_weighted_average_price_as     prices                                        NaN
#                                            downward_weighted_average_price_margin prices                                        NaN
#                                            downward_weighted_average_price_mfrr   prices                                        NaN
#                                            downward_weighted_average_price_rr     prices                                        NaN
#                                            upward_marginal_price                  prices                                        NaN
#                                            upward_marginal_price_as               prices                                        NaN
#                                            upward_marginal_price_margin           prices                                        NaN
#                                            upward_weighted_average_price          prices                                        NaN
#                                            upward_weighted_average_price_as       prices                                        NaN
#                                            upward_weighted_average_price_margin   prices                                        NaN
#                                            upward_weighted_average_price_mfrr     prices                                        NaN
#                                            upward_weighted_average_price_rr       prices                                        NaN
# procured_reserves                          AFRR                                   price                                         NaN
#                                                                                   value                                         NaN
#                                            FCR                                    price                                         NaN
#                                                                                   value                                         NaN
#                                            MFRR                                   price                                         NaN
#                                                                                   value                                         NaN
#                                            RR                                     price                                         NaN
#                                                                                   value                                         NaN
# transmission_network_unavailabilities      FORCED_UNAVAILABILITY                  value                                         NaN
#                                                                                   version                                       NaN
#                                            PLANNED_MAINTENANCE                    value                                         NaN
#                                                                                   version                                       NaN
# tso_offers                                 NG                                     downward_volume                               NaN
#                                                                                   maximum_downward_price                        NaN
#                                                                                   maximum_upward_price                          NaN
#                                                                                   minimum_downward_price                        NaN
#                                                                                   minimum_upward_price                          NaN
#                                                                                   upward_volume                                 NaN
#                                            REE                                    downward_volume                               NaN
#                                                                                   maximum_downward_price                        NaN
#                                                                                   maximum_upward_price                          NaN
#                                                                                   minimum_downward_price                        NaN
#                                                                                   minimum_upward_price                          NaN
#                                                                                   upward_volume                                 NaN
#                                            RTE                                    downward_volume                               NaN
#                                                                                   maximum_downward_price                        NaN
#                                                                                   maximum_upward_price                          NaN
#                                                                                   minimum_downward_price                        NaN
#                                                                                   minimum_upward_price                          NaN
#                                                                                   upward_volume                                 NaN
# water_reserves                             value                                  water_reserves                                NaN

# %%
description_df.columns.levels[0].unique
# Out:
# <bound method Index.unique of Index([u'available_value', u'direction', u'downward_volume', u'end_date',
#        u'installed_capacity', u'load_factor', u'maximum_downward_price',
#        u'maximum_upward_price', u'minimum_downward_price',
#        u'minimum_upward_price', u'nature', u'price', u'required_value',
#        u'start_date', u'updated_date', u'upward_volume', u'value', u'version',
#        u'voltage_level_connection'],
#       dtype='object')>

# %%
for res_name in res_names:
    
    if not data[res_name].empty:
        if (dividers[res_name] != None 
            and any(dividers[res_name] in s for s in data[res_name].columns.values)):
            groups = data[res_name].groupby([dividers[res_name]])
            groups.plot(x='start_date', y='value', marker='.',figsize=(20,10))
        else:
            data[res_name].plot(x='start_date', y='value', marker='.',figsize=(20,10))
    
    groups.plot(x='start_date', y='value', marker='.',figsize=(20,10))
    plt.xticks(rotation=30)
    plt.legend(fontsize=15)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-245-acfd1a7d13b5> in <module>()
#       6             and any(dividers[res_name] in s for s in data[res_name].columns.values)):
#       7             groups = data[res_name].groupby([dividers[res_name]])
# ----> 8             groups.plot(x='start_date', y='value', marker='.',figsize=(20,10))
#       9         else:
#      10             data[res_name].plot(x='start_date', y='value', marker='.',figsize=(20,10))
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\groupby.pyc in __call__(self, *args, **kwargs)
#     347             return self.plot(*args, **kwargs)
#     348         f.__name__ = 'plot'
# --> 349         return self._groupby.apply(f)
#     350
#     351     def __getattr__(self, name):
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\groupby.pyc in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\groupby.pyc in _python_apply_general(self, f)
#     718     def _python_apply_general(self, f):
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 720                                                    self.axis)
#     721
#     722         return self._wrap_applied_output(
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\groupby.pyc in apply(self, f, data, axis)
#    1800             # group might be modified
#    1801             group_axes = _get_axes(group)
# -> 1802             res = f(group)
#    1803             if not _is_indexed_like(res, group_axes):
#    1804                 mutated = True
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\groupby.pyc in f(self)
#     345     def __call__(self, *args, **kwargs):
#     346         def f(self):
# --> 347             return self.plot(*args, **kwargs)
#     348         f.__name__ = 'plot'
#     349         return self._groupby.apply(f)
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\plotting\_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\plotting\_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1678                     y = data.columns[y]
#    1679                 label = kwds['label'] if 'label' in kwds else y
# -> 1680                 series = data[y].copy()  # Don't modify
#    1681                 series.name = label
#    1682
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'value'

# %%
# Provide the path to the yaml file relative to the working directory
display(HTML('''<style>
    .widget-label { min-width: 20ex !important; }
    .widget-text { min-width: 60ex !important; }
</style>'''))

#Toggle Code
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();

 } else {
 $('div.input').show();

 }
 code_show = !code_show
} 
//$( document ).ready(code_toggle);//commenting code disabling by default
</script>
<form action = "javascript:code_toggle()"><input type="submit" value="Toggle Raw Code"></form>''')
# Out:
# <style>
#     .widget-label { min-width: 20ex !important; }
#     .widget-text { min-width: 60ex !important; }
# </style>
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#
#  } else {
#  $('div.input').show();
#
#  }
#  code_show = !code_show
# }
# //$( document ).ready(code_toggle);//commenting code disabling by default
# </script>
# <form action = "javascript:code_toggle()"><input type="submit" value="Toggle Raw Code"></form>
