# %%
import os
import sys;reload(sys);sys.setdefaultencoding('UTF8')
import itertools

import chardet
import json

import time

import pydocumentdb.documents as documents
import pydocumentdb.document_client as document_client
import pydocumentdb.errors as errors
import pydocumentdb.http_constants as http_constants

import pandas as pd; pd.options.display.max_rows = 36; pd.options.display.max_columns = 38
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np

import view.config as cfg
import view.storage as st

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from IPython.core.display import HTML
from IPython.display import display

# %%
HOST = cfg.settings.host
MASTER_KEY = cfg.settings.master_key
DATABASE_ID = cfg.settings.database_id
COLLECTION_ID = cfg.settings.collection_id
COLLECTION_ID = "rte4"

# %%
client = document_client.DocumentClient(HOST, {'masterKey': MASTER_KEY})
coll_link = st.GetCollectionLink(client, DATABASE_ID, COLLECTION_ID)

# %%
res_names = ["imbalance_data", "insufficients_offers", "prices", "peak_daily_margins", "signals",
             "volumes_per_energy_type","procured_reserves", "accepted_offers"]

# %%
proc_id = "ReadResources"
options = { 'enableScriptLogging': True }
params = {
    "resources": res_names,
    "start": "2016-01-01T00:00:00+02:00",
    "end": "2017-12-31T23:30:00+01:00",
    "options" : {
        "pageSize":50,
        "enableScan" : True,
        "continuation": None
    }
}
results = []

while True:
    response = st.ExecuteProcedure( client, coll_link, proc_id, params, options )
    results = results + response["queryResponse"]
    if not "lastContinuationToken" in response.viewkeys() or response["lastContinuationToken"] == None:
        break
    else:
        params["options"]["continuation"] = response["lastContinuationToken"]
# Out:
# |==12752==||==10602==||==9371==||==9369==||==9376==||==9343==||==9353==||==9358==||==9358==||==9352==||==9350==||==9353==||==9358==||==9361==||==9355==||==9356==||==9361==||==9355==||==9355==||==9363==||==9357==||==9363==||==9356==||==334824==|
# |==635146==||==634505==||==635250==||==637005==|
# |==637005==||==635559==||==637083==||==640284==|
# |==640284==||==643598==||==638623==||==641377==|
# |==641377==||==641275==||==641129==||==1396099==|
# |==1396099==||==1718208==|
# |==1718208==||==1718655==|
# |==1718655==||==1265434==|
# |==1265434==||==1718071==|
# |==1718071==||==1716728==|
# |==1716728==||==1718975==|
# |==1718975==||==1717748==|
# |==1717748==||==1719167==|
# |==1719167==||==1717207==|
# |==1717207==||==1716557==|
# |==1716557==||==1716918==|
# |==1716918==||==1713495==|
# |==1713495==||==1032179==|
# |==1032179==||==7051==||==7051==||==7051==||==7051==||==7051==||==7043==||==7047==||==7051==||==7051==||==7051==||==7050==||==7040==||==473537==|
# |==380079==||==382365==||==380889==||==379751==||==380866==||==382163==|
# |==382163==||==659787==||==764584==||==761062==|
# |==761062==||==502078==||==379751==||==381732==||==382164==|
# |==382164==||==751025==||==766479==||==760458==|
# |==760458==||==530718==||==880356==|
# |==880356==||==729957==||==993235==|
# |==993235==||==889335==||==768968==|
# |==768968==||==618762==||==763515==|
# |==763515==||==1123876==||==1138054==|
# |==1138054==||==1145980==|
# |==1145980==||==1054382==|
# |==1054382==||==769116==||==765888==|
# |==765888==||==762920==||==957321==|
# |==957321==||==956135==||==1014039==|
# |==1014039==||==908822==||==767680==|
# |==767680==||==768552==||==763704==|
# |==763704==||==762667==||==758951==|
# |==758951==||==760015==||==763761==|
# |==763761==||==765368==||==767932==|
# |==767932==||==765706==||==763402==|
# |==763402==||==761043==||==766526==|
# |==766526==||==596547==||==415751==||==415792==|
# |==415792==||==418195==||==417840==||==416658==||==417793==||==414407==|
# |==414407==||==410951==||==411569==||==415751==||==415751==||==415751==|
# |==415751==||==415741==||==416291==||==418203==||==416540==||==416807==|
# |==416807==||==849173==||==1684577==|
# |==1684577==||==1685204==|
# |==1685204==||==1688079==|
# |==1688079==||==1688950==|
# |==1688950==||==1689292==|
# |==1689292==||==1686225==|
# |==1686225==||==1691650==|
# |==1691650==||==1690510==|
# |==1690510==||==1688738==|
# |==1688738==||==473013==|
# |==473013==|

# %%
res_names
# Out:
# ['accepted_offers']

# %%
df = pd.DataFrame(results).drop_duplicates()
df.set_index(["start_date","end_date"], inplace=True)
valueList = list(df.select_dtypes(include=["int","float","float64","long"]).columns)

stat = []

for res_name in df.resource.unique():
    
    sub_df = df[df.resource == res_name]
    
    for value_type in valueList:
        serie = sub_df[value_type].dropna()
        if not serie.empty:
            
            nth = pd.date_range(
                start=serie.index.get_level_values("start_date").astype(np.datetime64).min(), 
                end=serie.index.get_level_values("end_date").astype(np.datetime64).max(), 
                freq='30T')
        
            stat.append({
                "resource":res_name,
                "type": value_type,
                "début": serie.index.get_level_values("start_date").astype(np.datetime64).min(),
                "fin": serie.index.get_level_values("end_date").astype(np.datetime64).max(),
                "manquant": str(nth.shape[0]-serie.index.get_level_values("start_date").unique().shape[0])+" / "+str(nth.shape[0])
            })

df = pd.DataFrame(stat)
df.set_index(['resource','type'])
# Out:
#                                                                                       début  \
# resource                type
# peak_daily_margins      available_value                                 2016-01-01 10:30:00
#                         required_value                                  2016-01-01 10:30:00
# imbalance_data          imbalance                                       2017-04-06 22:00:00
#                         negative_imbalance_settlement_price             2016-01-01 23:00:00
#                         positive_imbalance_settlement_price             2016-01-01 23:00:00
# prices                  downward_marginal_price                         2016-01-01 23:00:00
#                         downward_marginal_price_as                      2017-04-06 22:00:00
#                         downward_marginal_price_margin                  2017-04-06 22:00:00
#                         downward_weighted_average_price                 2016-01-01 23:00:00
#                         downward_weighted_average_price_as              2017-04-06 22:00:00
#                         downward_weighted_average_price_margin          2017-04-06 22:00:00
#                         downward_weighted_average_price_mfrr            2017-04-06 22:00:00
#                         downward_weighted_average_price_rr              2017-04-06 22:00:00
#                         upward_marginal_price                           2016-01-01 23:00:00
#                         upward_marginal_price_as                        2017-04-06 22:00:00
#                         upward_marginal_price_margin                    2017-04-06 22:00:00
#                         upward_weighted_average_price                   2016-01-01 23:00:00
#                         upward_weighted_average_price_as                2017-04-06 22:00:00
# ...                                                                                     ...
#                         upward_weighted_average_price_rr                2017-04-06 22:00:00
# volumes_per_energy_type countertrading_xb_redispatching_exported_volume 2016-06-02 22:00:00
#                         countertrading_xb_redispatching_imported_volume 2016-06-02 22:00:00
#                         deltap_volume                                   2017-03-03 23:00:00
#                         downward_volume_afrr                            2016-11-02 23:00:00
#                         downward_volume_fcr                             2016-11-02 23:00:00
#                         downward_volume_mfrr                            2016-06-02 22:30:00
#                         downward_volume_rr                              2016-11-13 15:00:00
#                         imbalance_netting_volume                        2017-04-06 22:00:00
#                         tso_mutual_emergency_exported_volume            2017-02-05 23:00:00
#                         tso_mutual_emergency_imported_volume            2017-02-05 23:00:00
#                         upward_volume_afrr                              2016-11-02 23:00:00
#                         upward_volume_fcr                               2016-11-02 23:00:00
#                         upward_volume_mfrr                              2016-06-02 22:00:00
#                         upward_volume_rr                                2016-11-07 17:00:00
#                         xb_balancing_exported_volume                    2016-06-02 22:00:00
#                         xb_balancing_imported_volume                    2016-06-02 22:00:00
# procured_reserves       price                                           2015-12-31 23:00:00
#
#                                                                                         fin  \
# resource                type
# peak_daily_margins      available_value                                 2017-10-23 18:30:00
#                         required_value                                  2017-10-23 18:30:00
# imbalance_data          imbalance                                       2017-10-24 22:00:00
#                         negative_imbalance_settlement_price             2017-10-24 22:00:00
#                         positive_imbalance_settlement_price             2017-10-24 22:00:00
# prices                  downward_marginal_price                         2017-10-24 22:00:00
#                         downward_marginal_price_as                      2017-10-24 22:00:00
#                         downward_marginal_price_margin                  2017-10-24 22:00:00
#                         downward_weighted_average_price                 2017-10-24 22:00:00
#                         downward_weighted_average_price_as              2017-10-24 22:00:00
#                         downward_weighted_average_price_margin          2017-10-24 22:00:00
#                         downward_weighted_average_price_mfrr            2017-10-24 22:00:00
#                         downward_weighted_average_price_rr              2017-10-24 22:00:00
#                         upward_marginal_price                           2017-10-24 22:00:00
#                         upward_marginal_price_as                        2017-10-24 22:00:00
#                         upward_marginal_price_margin                    2017-10-24 22:00:00
#                         upward_weighted_average_price                   2017-10-24 22:00:00
#                         upward_weighted_average_price_as                2017-10-24 22:00:00
# ...                                                                                     ...
#                         upward_weighted_average_price_rr                2017-10-24 22:00:00
# volumes_per_energy_type countertrading_xb_redispatching_exported_volume 2017-10-30 23:00:00
#                         countertrading_xb_redispatching_imported_volume 2017-10-30 23:00:00
#                         deltap_volume                                   2017-10-30 23:00:00
#                         downward_volume_afrr                            2017-10-30 23:00:00
#                         downward_volume_fcr                             2017-10-30 23:00:00
#                         downward_volume_mfrr                            2017-10-30 23:00:00
#                         downward_volume_rr                              2017-10-30 23:00:00
#                         imbalance_netting_volume                        2017-10-30 23:00:00
#                         tso_mutual_emergency_exported_volume            2017-10-30 23:00:00
#                         tso_mutual_emergency_imported_volume            2017-10-30 23:00:00
#                         upward_volume_afrr                              2017-10-30 23:00:00
#                         upward_volume_fcr                               2017-10-30 23:00:00
#                         upward_volume_mfrr                              2017-10-30 23:00:00
#                         upward_volume_rr                                2017-10-30 12:00:00
#                         xb_balancing_exported_volume                    2017-10-30 23:00:00
#                         xb_balancing_imported_volume                    2017-10-30 23:00:00
# procured_reserves       price                                           2017-10-29 23:00:00
#
#                                                                                missing
# resource                type
# peak_daily_margins      available_value                                  30658 / 31745
#                         required_value                                   30658 / 31745
# imbalance_data          imbalance                                             1 / 9649
#                         negative_imbalance_settlement_price                  1 / 31775
#                         positive_imbalance_settlement_price                  1 / 31775
# prices                  downward_marginal_price                            865 / 31775
#                         downward_marginal_price_as                           97 / 9649
#                         downward_marginal_price_margin                       97 / 9649
#                         downward_weighted_average_price                    865 / 31775
#                         downward_weighted_average_price_as                   97 / 9649
#                         downward_weighted_average_price_margin               97 / 9649
#                         downward_weighted_average_price_mfrr                 97 / 9649
#                         downward_weighted_average_price_rr                   97 / 9649
#                         upward_marginal_price                              865 / 31775
#                         upward_marginal_price_as                             97 / 9649
#                         upward_marginal_price_margin                         97 / 9649
#                         upward_weighted_average_price                      865 / 31775
#                         upward_weighted_average_price_as                     97 / 9649
# ...                                                                                ...
#                         upward_weighted_average_price_rr                     97 / 9649
# volumes_per_energy_type countertrading_xb_redispatching_exported_volume   1639 / 24723
#                         countertrading_xb_redispatching_imported_volume   1639 / 24723
#                         deltap_volume                                     2305 / 11569
#                         downward_volume_afrr                               964 / 17377
#                         downward_volume_fcr                                964 / 17377
#                         downward_volume_mfrr                              9063 / 24722
#                         downward_volume_rr                               13678 / 16865
#                         imbalance_netting_volume                            678 / 9939
#                         tso_mutual_emergency_exported_volume              8497 / 12817
#                         tso_mutual_emergency_imported_volume              8497 / 12817
#                         upward_volume_afrr                                 964 / 17377
#                         upward_volume_fcr                                  964 / 17377
#                         upward_volume_mfrr                               12028 / 24723
#                         upward_volume_rr                                 14007 / 17127
#                         xb_balancing_exported_volume                      1639 / 24723
#                         xb_balancing_imported_volume                      1639 / 24723
# procured_reserves       price                                            12245 / 32065
#
# [38 rows x 3 columns]

# %%
writer = pd.ExcelWriter(".\Rapports_Etude_MA\Relation_Alert_Prix_MA\Csv\Data_availability.xlsx", engine='xlsxwriter')

df.to_excel(writer,sheet_name="2016-2017",index=False, na_rep="-", encoding='utf-8')
# Close the Pandas Excel writer and output the Excel file.
writer.save()
