# %%
import pandas as pd; pd.options.display.max_rows =40; pd.options.display.max_columns =100
from pandasql import sqldf
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns; sns.set(style="whitegrid", color_codes=True)
import numpy as np

import view.config as cfg
import view.storage as st
import view.normalization as norm
import view.analyze as ana
import view.wrangler as wg
import view.sql_requests as rq

from IPython.core.display import HTML
from IPython.display import display

import pydocumentdb.documents as documents
import pydocumentdb.document_client as document_client
import pydocumentdb.errors as errors
import pydocumentdb.http_constants as http_constants

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

import types
import itertools

# %%
def GetDataFromCosmos(HOST, MASTER_KEY, DATABASE_ID, COLLECTION_ID, proc_id, params, options):
    dodocs = None
    try:
        client = document_client.DocumentClient(HOST, {'masterKey': MASTER_KEY})
        
        coll_link = st.GetCollectionLink(client, DATABASE_ID, COLLECTION_ID)
        
        dodocs = st.ExecuteProcedure( client, coll_link, proc_id, params, options )
    except BaseException as e:
        raise e
    
    return dodocs
    
def MergeCosmosData( dodocs ):
    
    data = []
    
    for key, value in dodocs.iteritems():
        df = pd.DataFrame(value)
        df["resource"] = key
        data.append(df)
        
    data = norm.FindProbableFloat(data)
    df = pd.concat(data, axis=0)
    
    return df

def MarkInsufficientOffers( df ):
    
    for index, row in df[df.resource == "insufficients_offers"].iterrows():
        if row.type == "DOWNGRADED":
            condition = np.logical_and(df.start_date >= row.start_date, df.start_date < row.end_date)
            df.loc[condition, "downgraded"] = row["nature"]
        elif row.type == "WARNING":
            condition = np.logical_and(df.start_date >= row.start_date, df.start_date < row.end_date)
            df.loc[condition, "alert"] = row["nature"]
    
    return df

def MarkPPDay( df ):
    for index, row in df[df.type == "PP2"].iterrows():
        if row.value:
            condition = np.logical_and(df.start_date >= row.start_date, df.start_date < row.end_date)
            df.loc[condition, "PP"] = row.type
    for index, row in df[df.type == "PP1"].iterrows():
        if row.value:
            condition = np.logical_and(df.start_date >= row.start_date, df.start_date < row.end_date)
            df.loc[condition, "PP"] = row.type
            
    return df

def Row2Categories ( df, resources ):
    for resource in resources:
        if resource == "insufficients_offers":
            df["alert"] = "NORMAL"
            df["downgraded"] = "NORMAL"
            df = MarkInsufficientOffers( df )
            df = df[df.resource != "insufficients_offers"] # Drop Rows
        
        elif resource == "signals":
            df["PP"] = "NORMAL"
            df = MarkPPDay( df )
            df = df[df.resource != "signals"]
    return df

def update_startend(x, df1, freq):
    if x.name < df1.shape[0]:
        x.end_date = x.start_date + pd.Timedelta(freq)
    else:
        x.start_date = x.end_date - pd.Timedelta(freq)
    return x

def PropagateData( df, resources, freq='30 min' ):
    
    for resource in resources:
        if resource in ["peak_daily_margins"]:
            
            df0 = df[df.resource == resource]

            df1 = df0.set_index("start_date").resample(freq).pad().reset_index()
            df2 = df0.set_index("end_date").resample(freq).bfill().reset_index()
            df3 = pd.concat([df1, df2], ignore_index=True)


            df3 = df3[ df3.start_date < df3.end_date ].apply(lambda x: update_startend(x, df1, freq), axis=1)

            df = df[df.resource != resource]
            df = df.append(df3, ignore_index=True)
    return df

def MergeColumns( df ):
    cols = list(df.columns.values)
    
    if set(["direction", "system_trend"]).issubset(set(cols)):
        df.loc[df.system_trend.isnull() == False, "direction"] = df.loc[df.system_trend.isnull() == False, "system_trend"].map({'HAUSSE': 'UPWARD', 'BAISSE': 'DOWNWARD', 'NULLE': 'UP_DOWN'})
    
    return df

def GetMarket(cfg, params, options):
    try:
        dodocs = GetDataFromCosmos(cfg["HOST"], cfg["MASTER_KEY"], cfg["DATABASE_ID"], cfg["COLLECTION_ID"], cfg["PROCEDURE_ID"], params, options)
    
        data = []

        df = MergeCosmosData( dodocs )
        
        # Drop Pulicates data
        df.drop_duplicates(keep='first', inplace=True)
        
        # fillna here
        
        df = MergeColumns( df )
        
        if "direction" in df.reset_index().columns:
            df.loc[df.direction.isnull(),"direction"] = "UP_DOWN"
    
        # Set date columns as normalized datetime columns
        df[["start_date", "end_date"]]= df[["start_date", "end_date"]].astype(np.datetime64)
        df = df[df.start_date < df.end_date]
        
        df = PropagateData( df, params["resources"], '30 min' )
        
        df = Row2Categories ( df, params["resources"] )

        valueList = list(df.select_dtypes(include=["int","float","long"]).columns) #["available_value","price", "required_value", "value"]
        
        if not valueList ==[] :
            table_df = pd.pivot_table(
                        df,
                        values=valueList,
                        index=cfg["index"],
                        aggfunc= 'first')
            print table_df.reset_index().resource.unique()
            # Go from multi columns to cube
            level = len(cfg["index"])
            table_df = table_df.stack(0).reset_index(level)
            table_df = table_df.rename(index=str, columns={"level_"+str(level): "value_type"})

            # Set date columns as normalized datetime columns
            table_df = table_df.reset_index()
            table_df[["start_date", "end_date"]]= table_df[["start_date", "end_date"]].astype(np.datetime64)


            # Set multi index dataframe
            table_df = table_df.set_index(cfg["index"]+["value_type"])
            table_df = table_df.rename(index=str, columns={0:"value"})
    except BaseException as e:
        print e
            
    return df

# %%
config = {
    "HOST" : cfg.settings.host,
    "MASTER_KEY" : cfg.settings.master_key,
    "DATABASE_ID" : cfg.settings.database_id,
    "COLLECTION_ID" : cfg.settings.collection_id,
    "PROCEDURE_ID" : "ReadResources",
    "index" : ['start_date','end_date','resource','direction','PP','alert','downgraded']
}
print config

res_names = ["procured_reserves", "imbalance_data", "insufficients_offers", "prices", "peak_daily_margins", "signals"]
options = { 
    "enableScriptLogging": True}
params = {
    "resources": res_names, 
    "start": "2017-01-01T00:00:00+02:00",
    "end": "2017-02-31T23:30:00+01:00",
    "options" : {
        "pageSize":-1
    }
}

dodocs = GetMarket(config, params, options)
# Out:
# {'index': ['start_date', 'end_date', 'resource', 'direction', 'PP', 'alert', 'downgraded'], 'MASTER_KEY': 'C2y6yDjf5/R+ob0N8A7Cgv30VRDJIWEHLM+4QDU5DE2nQ9nDuVTqobD4b8mGGyPMbIZnqyMsEcaGQy67XIw/Jw==', 'DATABASE_ID': 'LaSD', 'HOST': 'https://localhost:8081', 'COLLECTION_ID': 'rte2', 'PROCEDURE_ID': 'ReadResources'}
# None
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [u'imbalance_data' u'prices' u'signals' u'peak_daily_margins']

# %%
dodocs[dodocs.PP != "NORMAL"]
# Out:
#       available_value direction  downward_marginal_price  \
# 82                NaN   UP_DOWN                      0.0
# 83                NaN   UP_DOWN                      0.0
# 84                NaN   UP_DOWN                     61.6
# 85                NaN   UP_DOWN                     45.3
# 86                NaN   UP_DOWN                      0.0
# 87                NaN   UP_DOWN                      0.0
# 88                NaN   UP_DOWN                      0.0
# 89                NaN   UP_DOWN                     71.6
# 90                NaN   UP_DOWN                      0.0
# 91                NaN   UP_DOWN                     75.1
# 92                NaN   UP_DOWN                     63.9
# 93                NaN   UP_DOWN                     56.6
# 94                NaN   UP_DOWN                     56.6
# 95                NaN   UP_DOWN                     68.5
# 96                NaN   UP_DOWN                      0.0
# 97                NaN   UP_DOWN                      0.0
# 98                NaN   UP_DOWN                      0.0
# 99                NaN   UP_DOWN                      0.0
# 100               NaN   UP_DOWN                      0.0
# 101               NaN   UP_DOWN                      0.0
# ...               ...       ...                      ...
# 6294           4940.0   UP_DOWN                      NaN
# 6295           4940.0   UP_DOWN                      NaN
# 6296           4940.0   UP_DOWN                      NaN
# 6297           4940.0   UP_DOWN                      NaN
# 6298           5721.0   UP_DOWN                      NaN
# 6299           5721.0   UP_DOWN                      NaN
# 6300           5721.0   UP_DOWN                      NaN
# 6301           5721.0   UP_DOWN                      NaN
# 6302           5721.0   UP_DOWN                      NaN
# 6303           5721.0   UP_DOWN                      NaN
# 6304           5721.0   UP_DOWN                      NaN
# 6305           5721.0   UP_DOWN                      NaN
# 6306           5721.0   UP_DOWN                      NaN
# 6307           5721.0   UP_DOWN                      NaN
# 6308           5721.0   UP_DOWN                      NaN
# 6309           5721.0   UP_DOWN                      NaN
# 6310           8117.0   UP_DOWN                      NaN
# 6311           8117.0   UP_DOWN                      NaN
# 6312           8117.0   UP_DOWN                      NaN
# 6313           8117.0   UP_DOWN                      NaN
#
#       downward_marginal_price_as  downward_marginal_price_margin  \
# 82                           NaN                             NaN
# 83                           NaN                             NaN
# 84                           NaN                             NaN
# 85                           NaN                             NaN
# 86                           NaN                             NaN
# 87                           NaN                             NaN
# 88                           NaN                             NaN
# 89                           NaN                             NaN
# 90                           NaN                             NaN
# 91                           NaN                             NaN
# 92                           NaN                             NaN
# 93                           NaN                             NaN
# 94                           NaN                             NaN
# 95                           NaN                             NaN
# 96                           NaN                             NaN
# 97                           NaN                             NaN
# 98                           NaN                             NaN
# 99                           NaN                             NaN
# 100                          NaN                             NaN
# 101                          NaN                             NaN
# ...                          ...                             ...
# 6294                         NaN                             NaN
# 6295                         NaN                             NaN
# 6296                         NaN                             NaN
# 6297                         NaN                             NaN
# 6298                         NaN                             NaN
# 6299                         NaN                             NaN
# 6300                         NaN                             NaN
# 6301                         NaN                             NaN
# 6302                         NaN                             NaN
# 6303                         NaN                             NaN
# 6304                         NaN                             NaN
# 6305                         NaN                             NaN
# 6306                         NaN                             NaN
# 6307                         NaN                             NaN
# 6308                         NaN                             NaN
# 6309                         NaN                             NaN
# 6310                         NaN                             NaN
# 6311                         NaN                             NaN
# 6312                         NaN                             NaN
# 6313                         NaN                             NaN
#
#       downward_weighted_average_price  downward_weighted_average_price_as  \
# 82                              67.42                                 NaN
# 83                              68.73                                 NaN
# 84                              61.60                                 NaN
# 85                              56.81                                 NaN
# 86                             150.00                                 NaN
# 87                             150.00                                 NaN
# 88                             150.00                                 NaN
# 89                              71.60                                 NaN
# 90                             150.00                                 NaN
# 91                              75.10                                 NaN
# 92                              73.39                                 NaN
# 93                              63.66                                 NaN
# 94                              61.61                                 NaN
# 95                              68.50                                 NaN
# 96                             150.00                                 NaN
# 97                             150.00                                 NaN
# 98                             150.00                                 NaN
# 99                             150.00                                 NaN
# 100                            150.00                                 NaN
# 101                            150.00                                 NaN
# ...                               ...                                 ...
# 6294                              NaN                                 NaN
# 6295                              NaN                                 NaN
# 6296                              NaN                                 NaN
# 6297                              NaN                                 NaN
# 6298                              NaN                                 NaN
# 6299                              NaN                                 NaN
# 6300                              NaN                                 NaN
# 6301                              NaN                                 NaN
# 6302                              NaN                                 NaN
# 6303                              NaN                                 NaN
# 6304                              NaN                                 NaN
# 6305                              NaN                                 NaN
# 6306                              NaN                                 NaN
# 6307                              NaN                                 NaN
# 6308                              NaN                                 NaN
# 6309                              NaN                                 NaN
# 6310                              NaN                                 NaN
# 6311                              NaN                                 NaN
# 6312                              NaN                                 NaN
# 6313                              NaN                                 NaN
#
#       downward_weighted_average_price_margin  \
# 82                                       NaN
# 83                                       NaN
# 84                                       NaN
# 85                                       NaN
# 86                                       NaN
# 87                                       NaN
# 88                                       NaN
# 89                                       NaN
# 90                                       NaN
# 91                                       NaN
# 92                                       NaN
# 93                                       NaN
# 94                                       NaN
# 95                                       NaN
# 96                                       NaN
# 97                                       NaN
# 98                                       NaN
# 99                                       NaN
# 100                                      NaN
# 101                                      NaN
# ...                                      ...
# 6294                                     NaN
# 6295                                     NaN
# 6296                                     NaN
# 6297                                     NaN
# 6298                                     NaN
# 6299                                     NaN
# 6300                                     NaN
# 6301                                     NaN
# 6302                                     NaN
# 6303                                     NaN
# 6304                                     NaN
# 6305                                     NaN
# 6306                                     NaN
# 6307                                     NaN
# 6308                                     NaN
# 6309                                     NaN
# 6310                                     NaN
# 6311                                     NaN
# 6312                                     NaN
# 6313                                     NaN
#
#       downward_weighted_average_price_mfrr  \
# 82                                     NaN
# 83                                     NaN
# 84                                     NaN
# 85                                     NaN
# 86                                     NaN
# 87                                     NaN
# 88                                     NaN
# 89                                     NaN
# 90                                     NaN
# 91                                     NaN
# 92                                     NaN
# 93                                     NaN
# 94                                     NaN
# 95                                     NaN
# 96                                     NaN
# 97                                     NaN
# 98                                     NaN
# 99                                     NaN
# 100                                    NaN
# 101                                    NaN
# ...                                    ...
# 6294                                   NaN
# 6295                                   NaN
# 6296                                   NaN
# 6297                                   NaN
# 6298                                   NaN
# 6299                                   NaN
# 6300                                   NaN
# 6301                                   NaN
# 6302                                   NaN
# 6303                                   NaN
# 6304                                   NaN
# 6305                                   NaN
# 6306                                   NaN
# 6307                                   NaN
# 6308                                   NaN
# 6309                                   NaN
# 6310                                   NaN
# 6311                                   NaN
# 6312                                   NaN
# 6313                                   NaN
#
#       downward_weighted_average_price_rr            end_date  imbalance  \
# 82                                   NaN 2017-01-03 23:00:00        NaN
# 83                                   NaN 2017-01-03 23:00:00        NaN
# 84                                   NaN 2017-01-03 23:00:00        NaN
# 85                                   NaN 2017-01-03 23:00:00        NaN
# 86                                   NaN 2017-01-03 23:00:00        NaN
# 87                                   NaN 2017-01-03 23:00:00        NaN
# 88                                   NaN 2017-01-03 23:00:00        NaN
# 89                                   NaN 2017-01-03 23:00:00        NaN
# 90                                   NaN 2017-01-03 23:00:00        NaN
# 91                                   NaN 2017-01-03 23:00:00        NaN
# 92                                   NaN 2017-01-03 23:00:00        NaN
# 93                                   NaN 2017-01-03 23:00:00        NaN
# 94                                   NaN 2017-01-03 23:00:00        NaN
# 95                                   NaN 2017-01-03 23:00:00        NaN
# 96                                   NaN 2017-01-03 23:00:00        NaN
# 97                                   NaN 2017-01-03 23:00:00        NaN
# 98                                   NaN 2017-01-03 23:00:00        NaN
# 99                                   NaN 2017-01-03 23:00:00        NaN
# 100                                  NaN 2017-01-03 23:00:00        NaN
# 101                                  NaN 2017-01-03 23:00:00        NaN
# ...                                  ...                 ...        ...
# 6294                                 NaN 2017-01-26 17:30:00        NaN
# 6295                                 NaN 2017-01-26 18:00:00        NaN
# 6296                                 NaN 2017-01-26 18:30:00        NaN
# 6297                                 NaN 2017-01-26 19:00:00        NaN
# 6298                                 NaN 2017-01-27 06:30:00        NaN
# 6299                                 NaN 2017-01-27 07:00:00        NaN
# 6300                                 NaN 2017-01-27 07:30:00        NaN
# 6301                                 NaN 2017-01-27 08:00:00        NaN
# 6302                                 NaN 2017-01-27 08:30:00        NaN
# 6303                                 NaN 2017-01-27 09:00:00        NaN
# 6304                                 NaN 2017-01-27 09:30:00        NaN
# 6305                                 NaN 2017-01-27 10:00:00        NaN
# 6306                                 NaN 2017-01-27 10:30:00        NaN
# 6307                                 NaN 2017-01-27 11:00:00        NaN
# 6308                                 NaN 2017-01-27 11:30:00        NaN
# 6309                                 NaN 2017-01-27 12:00:00        NaN
# 6310                                 NaN 2017-01-27 17:30:00        NaN
# 6311                                 NaN 2017-01-27 18:00:00        NaN
# 6312                                 NaN 2017-01-27 18:30:00        NaN
# 6313                                 NaN 2017-01-27 19:00:00        NaN
#
#      missing_data_list nature  negative_imbalance_settlement_price  \
# 82                 NaN    NaN                                  NaN
# 83                 NaN    NaN                                  NaN
# 84                 NaN    NaN                                  NaN
# 85                 NaN    NaN                                  NaN
# 86                 NaN    NaN                                  NaN
# 87                 NaN    NaN                                  NaN
# 88                 NaN    NaN                                  NaN
# 89                 NaN    NaN                                  NaN
# 90                 NaN    NaN                                  NaN
# 91                 NaN    NaN                                  NaN
# 92                 NaN    NaN                                  NaN
# 93                 NaN    NaN                                  NaN
# 94                 NaN    NaN                                  NaN
# 95                 NaN    NaN                                  NaN
# 96                 NaN    NaN                                  NaN
# 97                 NaN    NaN                                  NaN
# 98                 NaN    NaN                                  NaN
# 99                 NaN    NaN                                  NaN
# 100                NaN    NaN                                  NaN
# 101                NaN    NaN                                  NaN
# ...                ...    ...                                  ...
# 6294               NaN    NaN                                  NaN
# 6295               NaN    NaN                                  NaN
# 6296               NaN    NaN                                  NaN
# 6297               NaN    NaN                                  NaN
# 6298               NaN    NaN                                  NaN
# 6299               NaN    NaN                                  NaN
# 6300               NaN    NaN                                  NaN
# 6301               NaN    NaN                                  NaN
# 6302               NaN    NaN                                  NaN
# 6303               NaN    NaN                                  NaN
# 6304               NaN    NaN                                  NaN
# 6305               NaN    NaN                                  NaN
# 6306               NaN    NaN                                  NaN
# 6307               NaN    NaN                                  NaN
# 6308               NaN    NaN                                  NaN
# 6309               NaN    NaN                                  NaN
# 6310               NaN    NaN                                  NaN
# 6311               NaN    NaN                                  NaN
# 6312               NaN    NaN                                  NaN
# 6313               NaN    NaN                                  NaN
#
#       positive_imbalance_settlement_price  required_value            resource  \
# 82                                    NaN             NaN              prices
# 83                                    NaN             NaN              prices
# 84                                    NaN             NaN              prices
# 85                                    NaN             NaN              prices
# 86                                    NaN             NaN              prices
# 87                                    NaN             NaN              prices
# 88                                    NaN             NaN              prices
# 89                                    NaN             NaN              prices
# 90                                    NaN             NaN              prices
# 91                                    NaN             NaN              prices
# 92                                    NaN             NaN              prices
# 93                                    NaN             NaN              prices
# 94                                    NaN             NaN              prices
# 95                                    NaN             NaN              prices
# 96                                    NaN             NaN              prices
# 97                                    NaN             NaN              prices
# 98                                    NaN             NaN              prices
# 99                                    NaN             NaN              prices
# 100                                   NaN             NaN              prices
# 101                                   NaN             NaN              prices
# ...                                   ...             ...                 ...
# 6294                                  NaN          3200.0  peak_daily_margins
# 6295                                  NaN          3200.0  peak_daily_margins
# 6296                                  NaN          3200.0  peak_daily_margins
# 6297                                  NaN          3200.0  peak_daily_margins
# 6298                                  NaN          4000.0  peak_daily_margins
# 6299                                  NaN          4000.0  peak_daily_margins
# 6300                                  NaN          4000.0  peak_daily_margins
# 6301                                  NaN          4000.0  peak_daily_margins
# 6302                                  NaN          4000.0  peak_daily_margins
# 6303                                  NaN          4000.0  peak_daily_margins
# 6304                                  NaN          4000.0  peak_daily_margins
# 6305                                  NaN          4000.0  peak_daily_margins
# 6306                                  NaN          4000.0  peak_daily_margins
# 6307                                  NaN          4000.0  peak_daily_margins
# 6308                                  NaN          4000.0  peak_daily_margins
# 6309                                  NaN          4000.0  peak_daily_margins
# 6310                                  NaN          3000.0  peak_daily_margins
# 6311                                  NaN          3000.0  peak_daily_margins
# 6312                                  NaN          3000.0  peak_daily_margins
# 6313                                  NaN          3000.0  peak_daily_margins
#
#               start_date system_trend     type  upward_marginal_price  \
# 82   2017-01-02 23:00:00          NaN      NaN                 131.96
# 83   2017-01-02 23:00:00          NaN      NaN                 131.96
# 84   2017-01-02 23:00:00          NaN      NaN                 131.96
# 85   2017-01-02 23:00:00          NaN      NaN                 131.96
# 86   2017-01-02 23:00:00          NaN      NaN                 131.96
# 87   2017-01-02 23:00:00          NaN      NaN                 131.96
# 88   2017-01-02 23:00:00          NaN      NaN                 131.96
# 89   2017-01-02 23:00:00          NaN      NaN                 131.96
# 90   2017-01-02 23:00:00          NaN      NaN                 131.96
# 91   2017-01-02 23:00:00          NaN      NaN                 131.96
# 92   2017-01-02 23:00:00          NaN      NaN                 131.96
# 93   2017-01-02 23:00:00          NaN      NaN                 131.96
# 94   2017-01-02 23:00:00          NaN      NaN                 131.96
# 95   2017-01-02 23:00:00          NaN      NaN                 131.96
# 96   2017-01-02 23:00:00          NaN      NaN                 131.96
# 97   2017-01-02 23:00:00          NaN      NaN                 131.96
# 98   2017-01-02 23:00:00          NaN      NaN                 131.96
# 99   2017-01-02 23:00:00          NaN      NaN                 131.96
# 100  2017-01-02 23:00:00          NaN      NaN                 131.96
# 101  2017-01-02 23:00:00          NaN      NaN                   0.00
# ...                  ...          ...      ...                    ...
# 6294 2017-01-26 17:00:00          NaN  EVENING                    NaN
# 6295 2017-01-26 17:30:00          NaN  EVENING                    NaN
# 6296 2017-01-26 18:00:00          NaN  EVENING                    NaN
# 6297 2017-01-26 18:30:00          NaN  EVENING                    NaN
# 6298 2017-01-27 06:00:00          NaN  MORNING                    NaN
# 6299 2017-01-27 06:30:00          NaN  MORNING                    NaN
# 6300 2017-01-27 07:00:00          NaN  MORNING                    NaN
# 6301 2017-01-27 07:30:00          NaN  MORNING                    NaN
# 6302 2017-01-27 08:00:00          NaN  MORNING                    NaN
# 6303 2017-01-27 08:30:00          NaN  MORNING                    NaN
# 6304 2017-01-27 09:00:00          NaN  MORNING                    NaN
# 6305 2017-01-27 09:30:00          NaN  MORNING                    NaN
# 6306 2017-01-27 10:00:00          NaN  MORNING                    NaN
# 6307 2017-01-27 10:30:00          NaN  MORNING                    NaN
# 6308 2017-01-27 11:00:00          NaN  MORNING                    NaN
# 6309 2017-01-27 11:30:00          NaN  MORNING                    NaN
# 6310 2017-01-27 17:00:00          NaN  EVENING                    NaN
# 6311 2017-01-27 17:30:00          NaN  EVENING                    NaN
# 6312 2017-01-27 18:00:00          NaN  EVENING                    NaN
# 6313 2017-01-27 18:30:00          NaN  EVENING                    NaN
#
#       upward_marginal_price_as  upward_marginal_price_margin  \
# 82                         NaN                           NaN
# 83                         NaN                           NaN
# 84                         NaN                           NaN
# 85                         NaN                           NaN
# 86                         NaN                           NaN
# 87                         NaN                           NaN
# 88                         NaN                           NaN
# 89                         NaN                           NaN
# 90                         NaN                           NaN
# 91                         NaN                           NaN
# 92                         NaN                           NaN
# 93                         NaN                           NaN
# 94                         NaN                           NaN
# 95                         NaN                           NaN
# 96                         NaN                           NaN
# 97                         NaN                           NaN
# 98                         NaN                           NaN
# 99                         NaN                           NaN
# 100                        NaN                           NaN
# 101                        NaN                           NaN
# ...                        ...                           ...
# 6294                       NaN                           NaN
# 6295                       NaN                           NaN
# 6296                       NaN                           NaN
# 6297                       NaN                           NaN
# 6298                       NaN                           NaN
# 6299                       NaN                           NaN
# 6300                       NaN                           NaN
# 6301                       NaN                           NaN
# 6302                       NaN                           NaN
# 6303                       NaN                           NaN
# 6304                       NaN                           NaN
# 6305                       NaN                           NaN
# 6306                       NaN                           NaN
# 6307                       NaN                           NaN
# 6308                       NaN                           NaN
# 6309                       NaN                           NaN
# 6310                       NaN                           NaN
# 6311                       NaN                           NaN
# 6312                       NaN                           NaN
# 6313                       NaN                           NaN
#
#       upward_weighted_average_price  upward_weighted_average_price_as  \
# 82                           109.49                               NaN
# 83                           111.86                               NaN
# 84                           122.96                               NaN
# 85                           126.13                               NaN
# 86                           124.14                               NaN
# 87                           119.20                               NaN
# 88                           113.10                               NaN
# 89                           120.59                               NaN
# 90                           122.70                               NaN
# 91                           127.68                               NaN
# 92                           127.76                               NaN
# 93                           128.09                               NaN
# 94                           127.60                               NaN
# 95                           120.26                               NaN
# 96                           116.84                               NaN
# 97                           102.99                               NaN
# 98                            98.14                               NaN
# 99                           100.00                               NaN
# 100                          116.48                               NaN
# 101                           71.66                               NaN
# ...                             ...                               ...
# 6294                            NaN                               NaN
# 6295                            NaN                               NaN
# 6296                            NaN                               NaN
# 6297                            NaN                               NaN
# 6298                            NaN                               NaN
# 6299                            NaN                               NaN
# 6300                            NaN                               NaN
# 6301                            NaN                               NaN
# 6302                            NaN                               NaN
# 6303                            NaN                               NaN
# 6304                            NaN                               NaN
# 6305                            NaN                               NaN
# 6306                            NaN                               NaN
# 6307                            NaN                               NaN
# 6308                            NaN                               NaN
# 6309                            NaN                               NaN
# 6310                            NaN                               NaN
# 6311                            NaN                               NaN
# 6312                            NaN                               NaN
# 6313                            NaN                               NaN
#
#       upward_weighted_average_price_margin  \
# 82                                     NaN
# 83                                     NaN
# 84                                     NaN
# 85                                     NaN
# 86                                     NaN
# 87                                     NaN
# 88                                     NaN
# 89                                     NaN
# 90                                     NaN
# 91                                     NaN
# 92                                     NaN
# 93                                     NaN
# 94                                     NaN
# 95                                     NaN
# 96                                     NaN
# 97                                     NaN
# 98                                     NaN
# 99                                     NaN
# 100                                    NaN
# 101                                    NaN
# ...                                    ...
# 6294                                   NaN
# 6295                                   NaN
# 6296                                   NaN
# 6297                                   NaN
# 6298                                   NaN
# 6299                                   NaN
# 6300                                   NaN
# 6301                                   NaN
# 6302                                   NaN
# 6303                                   NaN
# 6304                                   NaN
# 6305                                   NaN
# 6306                                   NaN
# 6307                                   NaN
# 6308                                   NaN
# 6309                                   NaN
# 6310                                   NaN
# 6311                                   NaN
# 6312                                   NaN
# 6313                                   NaN
#
#       upward_weighted_average_price_mfrr  upward_weighted_average_price_rr  \
# 82                                   NaN                               NaN
# 83                                   NaN                               NaN
# 84                                   NaN                               NaN
# 85                                   NaN                               NaN
# 86                                   NaN                               NaN
# 87                                   NaN                               NaN
# 88                                   NaN                               NaN
# 89                                   NaN                               NaN
# 90                                   NaN                               NaN
# 91                                   NaN                               NaN
# 92                                   NaN                               NaN
# 93                                   NaN                               NaN
# 94                                   NaN                               NaN
# 95                                   NaN                               NaN
# 96                                   NaN                               NaN
# 97                                   NaN                               NaN
# 98                                   NaN                               NaN
# 99                                   NaN                               NaN
# 100                                  NaN                               NaN
# 101                                  NaN                               NaN
# ...                                  ...                               ...
# 6294                                 NaN                               NaN
# 6295                                 NaN                               NaN
# 6296                                 NaN                               NaN
# 6297                                 NaN                               NaN
# 6298                                 NaN                               NaN
# 6299                                 NaN                               NaN
# 6300                                 NaN                               NaN
# 6301                                 NaN                               NaN
# 6302                                 NaN                               NaN
# 6303                                 NaN                               NaN
# 6304                                 NaN                               NaN
# 6305                                 NaN                               NaN
# 6306                                 NaN                               NaN
# 6307                                 NaN                               NaN
# 6308                                 NaN                               NaN
# 6309                                 NaN                               NaN
# 6310                                 NaN                               NaN
# 6311                                 NaN                               NaN
# 6312                                 NaN                               NaN
# 6313                                 NaN                               NaN
#
#       value   alert             downgraded   PP
# 82      NaN  NORMAL                 NORMAL  PP2
# 83      NaN  NORMAL                 NORMAL  PP2
# 84      NaN  NORMAL                 NORMAL  PP2
# 85      NaN  NORMAL                 NORMAL  PP2
# 86      NaN  NORMAL                 NORMAL  PP2
# 87      NaN  NORMAL                 NORMAL  PP2
# 88      NaN  NORMAL                 NORMAL  PP2
# 89      NaN  NORMAL                 NORMAL  PP2
# 90      NaN  NORMAL                 NORMAL  PP2
# 91      NaN  NORMAL                 NORMAL  PP2
# 92      NaN  NORMAL                 NORMAL  PP2
# 93      NaN  NORMAL                 NORMAL  PP2
# 94      NaN  NORMAL                 NORMAL  PP2
# 95      NaN  NORMAL                 NORMAL  PP2
# 96      NaN  NORMAL                 NORMAL  PP2
# 97      NaN  NORMAL                 NORMAL  PP2
# 98      NaN  NORMAL                 NORMAL  PP2
# 99      NaN  NORMAL                 NORMAL  PP2
# 100     NaN  NORMAL                 NORMAL  PP2
# 101     NaN  NORMAL                 NORMAL  PP2
# ...     ...     ...                    ...  ...
# 6294    NaN  NORMAL  BALANCE_SUPPLY_DEMAND  PP2
# 6295    NaN  NORMAL  BALANCE_SUPPLY_DEMAND  PP2
# 6296    NaN  NORMAL  BALANCE_SUPPLY_DEMAND  PP2
# 6297    NaN  NORMAL  BALANCE_SUPPLY_DEMAND  PP2
# 6298    NaN  NORMAL                 NORMAL  PP2
# 6299    NaN  NORMAL                 NORMAL  PP2
# 6300    NaN  NORMAL                 NORMAL  PP2
# 6301    NaN  NORMAL                 NORMAL  PP2
# 6302    NaN  NORMAL                 NORMAL  PP2
# 6303    NaN  NORMAL                 NORMAL  PP2
# 6304    NaN  NORMAL                 NORMAL  PP2
# 6305    NaN  NORMAL                 NORMAL  PP2
# 6306    NaN  NORMAL                 NORMAL  PP2
# 6307    NaN  NORMAL                 NORMAL  PP2
# 6308    NaN  NORMAL                 NORMAL  PP2
# 6309    NaN  NORMAL                 NORMAL  PP2
# 6310    NaN  NORMAL                 NORMAL  PP2
# 6311    NaN  NORMAL                 NORMAL  PP2
# 6312    NaN  NORMAL                 NORMAL  PP2
# 6313    NaN  NORMAL                 NORMAL  PP2
#
# [1875 rows x 33 columns]

# %% [markdown]
# ### Plot des courbes sur la période 1

# %%
print params["start"] + ' -> ' + params['end']
# Out:
# 2016-08-01T00:00:00+02:00 -> 2016-08-31T23:30:00+01:00

# %%
query_df = sqldf(
    rq.MA_query.format(
        procured_direction="UP_DOWN", 
        accepted_direction="DOWNWARD", 
        activated_direction="DOWNWARD", 
        downgraded="'NORMAL'",
        alert="''")
    , locals())
if not query_df.empty:
    query_df.set_index("start_date", inplace=True)
    query_df.plot(figsize=(40,20), colormap=cm.tab20)
    plt.legend(fontsize=20)
    plt.show()
else:
    print "query_df is empty"

# %% [markdown]
# ### Matrice de corrélation avec les cluster basés sur la corrélation de pearson

# %%
# Draw the full plot
sns.clustermap(query_df.corr(), center=0, cmap="vlag",
               linewidths=.75, figsize=(13, 13))
plt.show()

# %%
# direction_query_df = sqldf(
#     direction_query.format(
#         resource="accepted_offers", 
#         resource_type="MFRR", 
#         value_type="value", 
#         downgraded="'NORMAL'")
#     , locals())
# direction_query_df.set_index("start_date", inplace=True)
# direction_query_df.plot(figsize=(40,20), colormap=cm.tab20)
# plt.legend(fontsize=20)
# plt.show()

# %%
# g = sns.PairGrid(direction_query_df,
#                  x_vars=["weekday", "direction", "downgraded", "alert"],
#                  y_vars=list(direction_query_df.select_dtypes(include=["float",'long']).columns),
#                  aspect=.75, size=4)
# g.map(sns.violinplot, palette="pastel");
# g = sns.PairGrid(query_df,
#                  x_vars=["weekday", "direction", "downgraded", "alert"],
#                  y_vars=list(query_df.select_dtypes(include=["float",'long']).columns),
#                  aspect=.75, size=4)
# g.map(sns.violinplot, palette="pastel");
# plt.show()
# plt.show()

# %% [markdown]
# ### Prix ou Volume d'offres activés par type de réserves en fonction du jour de la semaine et de la direction sur la période 1

# %%
print params["start"] + ' -> ' + params['end']
# Out:
# 2017-01-01T00:00:00+02:00 -> 2017-01-31T23:30:00+01:00

# %%
weekday_query_df = sqldf(
    rq.weekday_query.format(
        table_df="table_df",
        resource="activated_offers",
        value_type="value", 
        downgraded="'NORMAL'",
        alert="'NORMAL'"),
    locals())

if not weekday_query_df.empty:
    curve_name = list(weekday_query_df.select_dtypes(include=["float",'long']).columns)[0]
    
    g = sns.FacetGrid(weekday_query_df, row='weekday', col='direction',margin_titles=True)
    g.map(sns.violinplot, curve_name, 'type',palette="pastel")
    plt.show()
else:
    print "weekday_query_df is empty"

# %% [markdown]
# ### Prix ou Volume d'offres activés par type de réserves en fonction du jour de la semaine et de la direction sur la période 2

# %%
print params2["start"] + ' -> ' + params2['end']
# Out:
# 2016-09-01T00:00:00+02:00 -> 2016-09-31T23:30:00+01:00

# %%
weekday_query_df2 = sqldf(
    rq.weekday_query.format(
        table_df="table_df2",
        resource="activated_offers",
        value_type="value", 
        downgraded="'NORMAL'",
        alert="''"),
    locals())

if not weekday_query_df2.empty:
    curve_name = list(weekday_query_df2.select_dtypes(include=["float",'long']).columns)[0]
    
    g = sns.FacetGrid(weekday_query_df2, row='weekday', col='direction',margin_titles=True)
    g.map(sns.violinplot, curve_name, 'type',palette="pastel")
    plt.show()
else:
    print "weekday_query_df is empty"

# %%
table_df.reset_index()[table_df.reset_index().alert == "BALANCE_SUPPLY_DEMAND"]
# Out:
#                 start_date             end_date           resource  type  \
# 2634   2017-01-03 06:00:00  2017-01-03 06:30:00    accepted_offers  AFRR
# 2635   2017-01-03 06:00:00  2017-01-03 06:30:00    accepted_offers  AFRR
# 2636   2017-01-03 06:00:00  2017-01-03 06:30:00    accepted_offers  AFRR
# 2637   2017-01-03 06:00:00  2017-01-03 06:30:00    accepted_offers   FCR
# 2638   2017-01-03 06:00:00  2017-01-03 06:30:00    accepted_offers   FCR
# ...                    ...                  ...                ...   ...
# 43047  2017-01-30 22:30:00  2017-01-30 23:00:00  procured_reserves   FCR
# 43048  2017-01-30 22:30:00  2017-01-30 23:00:00  procured_reserves  MFRR
# 43049  2017-01-30 22:30:00  2017-01-30 23:00:00  procured_reserves  MFRR
# 43050  2017-01-30 22:30:00  2017-01-30 23:00:00  procured_reserves    RR
# 43051  2017-01-30 22:30:00  2017-01-30 23:00:00  procured_reserves    RR
#
#       direction                  alert downgraded value_type    value
# 2634   DOWNWARD  BALANCE_SUPPLY_DEMAND     NORMAL      value   910.00
# 2635     UPWARD  BALANCE_SUPPLY_DEMAND     NORMAL      value   910.00
# 2636    UP_DOWN  BALANCE_SUPPLY_DEMAND     NORMAL      value   898.00
# 2637   DOWNWARD  BALANCE_SUPPLY_DEMAND     NORMAL      value   738.00
# 2638     UPWARD  BALANCE_SUPPLY_DEMAND     NORMAL      value   738.00
# ...         ...                    ...        ...        ...      ...
# 43047   UP_DOWN  BALANCE_SUPPLY_DEMAND     NORMAL      value   645.00
# 43048    UPWARD  BALANCE_SUPPLY_DEMAND     NORMAL      price     5.54
# 43049    UPWARD  BALANCE_SUPPLY_DEMAND     NORMAL      value  1373.00
# 43050    UPWARD  BALANCE_SUPPLY_DEMAND     NORMAL      price     3.42
# 43051    UPWARD  BALANCE_SUPPLY_DEMAND     NORMAL      value   307.00
#
# [4370 rows x 9 columns]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(141)
ax2 = fig.add_subplot(142)

g = sns.FacetGrid(weekday_query_df, row='weekday', col='direction',margin_titles=True)
g.map(sns.violinplot, curve_name, 'type',palette="pastel", ax=ax1)
# Close the FacetGrid figure which we don't need (g.fig)
plt.close(g.fig)

g = sns.FacetGrid(weekday_query_df, row='weekday', col='direction',margin_titles=True)
g.map(sns.violinplot, curve_name, 'type',palette="pastel", ax=ax2)
# Close the FacetGrid figure which we don't need (g.fig)
plt.close(g.fig)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-198-91218d6fe3bf> in <module>()
#      10 g = sns.FacetGrid(weekday_query_df, row='weekday', col='direction',margin_titles=True)
#      11 g.map(sns.violinplot, curve_name, 'type',palette="pastel", ax=ax2)
# ---> 12 print g.subplot_kws
#      13 get_ipython().magic(u'pinfo g')
#      14 # Close the FacetGrid figure which we don't need (g.fig)
#
# AttributeError: 'FacetGrid' object has no attribute 'subplot_kws'

# %%
# Provide the path to the yaml file relative to the working directory
display(HTML('''<style>
    .widget-label { min-width: 20ex !important; }
    .widget-text { min-width: 60ex !important; }
</style>'''))

#Toggle Code
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();

 } else {
 $('div.input').show();

 }
 code_show = !code_show
} 
//$( document ).ready(code_toggle);//commenting code disabling by default
</script>
<form action = "javascript:code_toggle()"><input type="submit" value="Toggle Raw Code"></form>''')
# Out:
# <style>
#     .widget-label { min-width: 20ex !important; }
#     .widget-text { min-width: 60ex !important; }
# </style>
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#
#  } else {
#  $('div.input').show();
#
#  }
#  code_show = !code_show
# }
# //$( document ).ready(code_toggle);//commenting code disabling by default
# </script>
# <form action = "javascript:code_toggle()"><input type="submit" value="Toggle Raw Code"></form>
