# %%
import os
import sys
import itertools

import chardet
import json

import time

import pydocumentdb.documents as documents
import pydocumentdb.document_client as document_client
import pydocumentdb.errors as errors
import pydocumentdb.http_constants as http_constants

import pandas as pd; pd.options.display.max_rows = 100
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np

import view.config as cfg
import view.storage as st
import activated_offers.ao_settings as aos
import activated_offers.ao_functions as aof

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from IPython.core.display import HTML
from IPython.display import display

# %%
HOST = cfg.settings.host
MASTER_KEY = cfg.settings.master_key
DATABASE_ID = cfg.settings.database_id
COLLECTION_ID = "dd"
COLLECTION_ID
# Out:
# 'dd'

# %%
TRADUCTION = aos.traduction
COLUMNS = aos.columns
TITLES = aos.titles
DOC_MODEL = aos.document_model
SEPARATORS = aos.separators

# %%
dirpath = r".\activated_offers\Data\\"
client = document_client.DocumentClient(HOST, {'masterKey': MASTER_KEY})

for file in os.listdir(dirpath):
    if file.endswith(".csv"):
        path = os.path.join(r".\activated_offers\Data\\", file)
        docs_df = aof.ReadCSV(path, SEPARATORS)

        docs_df = aof.NormalizeCSV(docs_df, COLUMNS, TRADUCTION)

        groups_df = docs_df.groupby(["Dates", "type"])

        dic = aof.CreateDictOfDocument(list(groups_df))
        start_end = aof.GetStartEnd(groups_df)

        coll_link = st.GetCollectionLink(client, DATABASE_ID, COLLECTION_ID)

        for key, data in dic.iteritems():
            
            DOC_MODEL["start_date"] = str(start_end[key]["start_date"])
            DOC_MODEL["end_date"] = str(start_end[key]["end_date"])
            DOC_MODEL["data"] = data
            
            client.CreateDocument(coll_link, DOC_MODEL, options=None)
# Out:
# {'confidence': 0.73, 'language': '', 'encoding': 'ISO-8859-1'}
# {'confidence': 0.73, 'language': '', 'encoding': 'ISO-8859-1'}
# (129586, 0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-508fb54a04e7> in <module>()
#       8         print docs_df.shape
#       9
# ---> 10         docs_df = aof.NormalizeCSV(docs_df, COLUMNS, TRADUCTION)
#      11
#      12         groups_df = docs_df.groupby(["Dates", "type"])
#
# C:\Users\hauretouze_m\source\repos\MA-Analysis\Analysis\Alpiq\activated_offers\ao_functions.py in NormalizeCSV(docs, columns, traduction)
#      23 def NormalizeCSV(docs, columns, traduction):
#      24     # Change the column titles
# ---> 25     docs.columns = columns
#      26
#      27     # Normalization of the columns
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\generic.pyc in __setattr__(self, name, value)
#    3092         try:
#    3093             object.__getattribute__(self, name)
# -> 3094             return object.__setattr__(self, name, value)
#    3095         except AttributeError:
#    3096             pass
#
# pandas\_libs\src\properties.pyx in pandas._libs.lib.AxisProperty.__set__ (pandas\_libs\lib.c:45255)()
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\generic.pyc in _set_axis(self, axis, labels)
#     471
#     472     def _set_axis(self, axis, labels):
# --> 473         self._data.set_axis(axis, labels)
#     474         self._clear_item_cache()
#     475
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\internals.pyc in set_axis(self, axis, new_labels)
#    2834             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2835                              'new values have %d elements' %
# -> 2836                              (old_len, new_len))
#    2837
#    2838         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 5 elements

# %%
path = r".\\activated_offers\\Data\\OffresAccepteeEtActivees_2015_A83.csv"
df = aof.ReadCSV(path, SEPARATORS)
df = aof.NormalizeCSV(df, COLUMNS, TRADUCTION)
# Out:
# {'confidence': 1.0, 'language': '', 'encoding': 'UTF-8-SIG'}
# {'confidence': 1.0, 'language': '', 'encoding': 'UTF-8-SIG'}

# %%
DOC_MODEL
# Out:
# {'actioncollection': 'scheduler',
#  'actionid': None,
#  'actiontype': 'rte',
#  'apiname': 'balancing_capacity',
#  'data': [{'direction': 'UPWARD',
#    'end_date': '2017-04-21 00:30:00',
#    'price': '402.0',
#    'start_date': '2017-04-21 00:00:00',
#    'type': 'aFRR',
#    'value': 220.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 00:30:00',
#    'price': '402.0',
#    'start_date': '2017-04-21 00:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 01:00:00',
#    'price': '402.0',
#    'start_date': '2017-04-21 00:30:00',
#    'type': 'aFRR',
#    'value': 4.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 01:00:00',
#    'price': '402.0',
#    'start_date': '2017-04-21 00:30:00',
#    'type': 'aFRR',
#    'value': 187.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 01:30:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 01:00:00',
#    'type': 'aFRR',
#    'value': 27.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 01:30:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 01:00:00',
#    'type': 'aFRR',
#    'value': 64.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 02:00:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 01:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 02:00:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 01:30:00',
#    'type': 'aFRR',
#    'value': 120.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 02:30:00',
#    'price': '352.0',
#    'start_date': '2017-04-21 02:00:00',
#    'type': 'aFRR',
#    'value': 89.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 02:30:00',
#    'price': '352.0',
#    'start_date': '2017-04-21 02:00:00',
#    'type': 'aFRR',
#    'value': 19.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 03:00:00',
#    'price': '352.0',
#    'start_date': '2017-04-21 02:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 03:00:00',
#    'price': '352.0',
#    'start_date': '2017-04-21 02:30:00',
#    'type': 'aFRR',
#    'value': 53.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 03:30:00',
#    'price': '354.0',
#    'start_date': '2017-04-21 03:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 03:30:00',
#    'price': '354.0',
#    'start_date': '2017-04-21 03:00:00',
#    'type': 'aFRR',
#    'value': 48.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 04:00:00',
#    'price': '354.0',
#    'start_date': '2017-04-21 03:30:00',
#    'type': 'aFRR',
#    'value': 1.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 04:00:00',
#    'price': '354.0',
#    'start_date': '2017-04-21 03:30:00',
#    'type': 'aFRR',
#    'value': 6.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 04:30:00',
#    'price': '359.0',
#    'start_date': '2017-04-21 04:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 04:30:00',
#    'price': '359.0',
#    'start_date': '2017-04-21 04:00:00',
#    'type': 'aFRR',
#    'value': 52.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 05:00:00',
#    'price': '359.0',
#    'start_date': '2017-04-21 04:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 05:00:00',
#    'price': '359.0',
#    'start_date': '2017-04-21 04:30:00',
#    'type': 'aFRR',
#    'value': 117.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 05:30:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 05:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 05:30:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 05:00:00',
#    'type': 'aFRR',
#    'value': 198.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 06:00:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 05:30:00',
#    'type': 'aFRR',
#    'value': 45.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 06:00:00',
#    'price': '371.0',
#    'start_date': '2017-04-21 05:30:00',
#    'type': 'aFRR',
#    'value': 3.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 06:30:00',
#    'price': '433.0',
#    'start_date': '2017-04-21 06:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 06:30:00',
#    'price': '433.0',
#    'start_date': '2017-04-21 06:00:00',
#    'type': 'aFRR',
#    'value': 151.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 07:00:00',
#    'price': '433.0',
#    'start_date': '2017-04-21 06:30:00',
#    'type': 'aFRR',
#    'value': 74.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 07:00:00',
#    'price': '433.0',
#    'start_date': '2017-04-21 06:30:00',
#    'type': 'aFRR',
#    'value': 8.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 07:30:00',
#    'price': '51.0',
#    'start_date': '2017-04-21 07:00:00',
#    'type': 'aFRR',
#    'value': 21.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 07:30:00',
#    'price': '51.0',
#    'start_date': '2017-04-21 07:00:00',
#    'type': 'aFRR',
#    'value': 52.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 08:00:00',
#    'price': '51.0',
#    'start_date': '2017-04-21 07:30:00',
#    'type': 'aFRR',
#    'value': 93.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 08:00:00',
#    'price': '51.0',
#    'start_date': '2017-04-21 07:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 08:30:00',
#    'price': '55.0',
#    'start_date': '2017-04-21 08:00:00',
#    'type': 'aFRR',
#    'value': 7.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 08:30:00',
#    'price': '55.0',
#    'start_date': '2017-04-21 08:00:00',
#    'type': 'aFRR',
#    'value': 98.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 09:00:00',
#    'price': '55.0',
#    'start_date': '2017-04-21 08:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 09:00:00',
#    'price': '55.0',
#    'start_date': '2017-04-21 08:30:00',
#    'type': 'aFRR',
#    'value': 152.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 09:30:00',
#    'price': '528.0',
#    'start_date': '2017-04-21 09:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 09:30:00',
#    'price': '528.0',
#    'start_date': '2017-04-21 09:00:00',
#    'type': 'aFRR',
#    'value': 215.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 10:00:00',
#    'price': '528.0',
#    'start_date': '2017-04-21 09:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 10:00:00',
#    'price': '528.0',
#    'start_date': '2017-04-21 09:30:00',
#    'type': 'aFRR',
#    'value': 214.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 10:30:00',
#    'price': '502.0',
#    'start_date': '2017-04-21 10:00:00',
#    'type': 'aFRR',
#    'value': 61.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 10:30:00',
#    'price': '502.0',
#    'start_date': '2017-04-21 10:00:00',
#    'type': 'aFRR',
#    'value': 39.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 11:00:00',
#    'price': '502.0',
#    'start_date': '2017-04-21 10:30:00',
#    'type': 'aFRR',
#    'value': 93.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 11:00:00',
#    'price': '502.0',
#    'start_date': '2017-04-21 10:30:00',
#    'type': 'aFRR',
#    'value': 16.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 11:30:00',
#    'price': '479.0',
#    'start_date': '2017-04-21 11:00:00',
#    'type': 'aFRR',
#    'value': 12.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 11:30:00',
#    'price': '479.0',
#    'start_date': '2017-04-21 11:00:00',
#    'type': 'aFRR',
#    'value': 48.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 12:00:00',
#    'price': '479.0',
#    'start_date': '2017-04-21 11:30:00',
#    'type': 'aFRR',
#    'value': 15.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 12:00:00',
#    'price': '479.0',
#    'start_date': '2017-04-21 11:30:00',
#    'type': 'aFRR',
#    'value': 50.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 12:30:00',
#    'price': '452.0',
#    'start_date': '2017-04-21 12:00:00',
#    'type': 'aFRR',
#    'value': 110.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 12:30:00',
#    'price': '452.0',
#    'start_date': '2017-04-21 12:00:00',
#    'type': 'aFRR',
#    'value': 17.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 13:00:00',
#    'price': '452.0',
#    'start_date': '2017-04-21 12:30:00',
#    'type': 'aFRR',
#    'value': 161.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 13:00:00',
#    'price': '452.0',
#    'start_date': '2017-04-21 12:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 13:30:00',
#    'price': '418.0',
#    'start_date': '2017-04-21 13:00:00',
#    'type': 'aFRR',
#    'value': 214.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 13:30:00',
#    'price': '418.0',
#    'start_date': '2017-04-21 13:00:00',
#    'type': 'aFRR',
#    'value': 5.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 14:00:00',
#    'price': '418.0',
#    'start_date': '2017-04-21 13:30:00',
#    'type': 'aFRR',
#    'value': 19.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 14:00:00',
#    'price': '418.0',
#    'start_date': '2017-04-21 13:30:00',
#    'type': 'aFRR',
#    'value': 57.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 14:30:00',
#    'price': '391.0',
#    'start_date': '2017-04-21 14:00:00',
#    'type': 'aFRR',
#    'value': 290.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 14:30:00',
#    'price': '391.0',
#    'start_date': '2017-04-21 14:00:00',
#    'type': 'aFRR',
#    'value': 8.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 15:00:00',
#    'price': '391.0',
#    'start_date': '2017-04-21 14:30:00',
#    'type': 'aFRR',
#    'value': 128.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 15:00:00',
#    'price': '391.0',
#    'start_date': '2017-04-21 14:30:00',
#    'type': 'aFRR',
#    'value': 24.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 15:30:00',
#    'price': '374.0',
#    'start_date': '2017-04-21 15:00:00',
#    'type': 'aFRR',
#    'value': 214.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 15:30:00',
#    'price': '374.0',
#    'start_date': '2017-04-21 15:00:00',
#    'type': 'aFRR',
#    'value': 2.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 16:00:00',
#    'price': '374.0',
#    'start_date': '2017-04-21 15:30:00',
#    'type': 'aFRR',
#    'value': 183.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 16:00:00',
#    'price': '374.0',
#    'start_date': '2017-04-21 15:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 16:30:00',
#    'price': '383.0',
#    'start_date': '2017-04-21 16:00:00',
#    'type': 'aFRR',
#    'value': 248.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 16:30:00',
#    'price': '383.0',
#    'start_date': '2017-04-21 16:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 17:00:00',
#    'price': '383.0',
#    'start_date': '2017-04-21 16:30:00',
#    'type': 'aFRR',
#    'value': 247.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 17:00:00',
#    'price': '383.0',
#    'start_date': '2017-04-21 16:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 17:30:00',
#    'price': '392.0',
#    'start_date': '2017-04-21 17:00:00',
#    'type': 'aFRR',
#    'value': 220.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 17:30:00',
#    'price': '392.0',
#    'start_date': '2017-04-21 17:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 18:00:00',
#    'price': '392.0',
#    'start_date': '2017-04-21 17:30:00',
#    'type': 'aFRR',
#    'value': 178.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 18:00:00',
#    'price': '392.0',
#    'start_date': '2017-04-21 17:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 18:30:00',
#    'price': '441.0',
#    'start_date': '2017-04-21 18:00:00',
#    'type': 'aFRR',
#    'value': 11.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 18:30:00',
#    'price': '441.0',
#    'start_date': '2017-04-21 18:00:00',
#    'type': 'aFRR',
#    'value': 203.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 19:00:00',
#    'price': '441.0',
#    'start_date': '2017-04-21 18:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 19:00:00',
#    'price': '441.0',
#    'start_date': '2017-04-21 18:30:00',
#    'type': 'aFRR',
#    'value': 141.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 19:30:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 19:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 19:30:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 19:00:00',
#    'type': 'aFRR',
#    'value': 178.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 20:00:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 19:30:00',
#    'type': 'aFRR',
#    'value': 15.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 20:00:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 19:30:00',
#    'type': 'aFRR',
#    'value': 16.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 20:30:00',
#    'price': '508.0',
#    'start_date': '2017-04-21 20:00:00',
#    'type': 'aFRR',
#    'value': 78.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 20:30:00',
#    'price': '508.0',
#    'start_date': '2017-04-21 20:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 21:00:00',
#    'price': '508.0',
#    'start_date': '2017-04-21 20:30:00',
#    'type': 'aFRR',
#    'value': 39.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 21:00:00',
#    'price': '508.0',
#    'start_date': '2017-04-21 20:30:00',
#    'type': 'aFRR',
#    'value': 8.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 21:30:00',
#    'price': '522.0',
#    'start_date': '2017-04-21 21:00:00',
#    'type': 'aFRR',
#    'value': 263.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 21:30:00',
#    'price': '522.0',
#    'start_date': '2017-04-21 21:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 22:00:00',
#    'price': '522.0',
#    'start_date': '2017-04-21 21:30:00',
#    'type': 'aFRR',
#    'value': 67.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 22:00:00',
#    'price': '522.0',
#    'start_date': '2017-04-21 21:30:00',
#    'type': 'aFRR',
#    'value': 93.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 22:30:00',
#    'price': '512.0',
#    'start_date': '2017-04-21 22:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 22:30:00',
#    'price': '512.0',
#    'start_date': '2017-04-21 22:00:00',
#    'type': 'aFRR',
#    'value': 308.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 23:00:00',
#    'price': '512.0',
#    'start_date': '2017-04-21 22:30:00',
#    'type': 'aFRR',
#    'value': 60.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 23:00:00',
#    'price': '512.0',
#    'start_date': '2017-04-21 22:30:00',
#    'type': 'aFRR',
#    'value': 118.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 23:30:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 23:00:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 23:30:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 23:00:00',
#    'type': 'aFRR',
#    'value': 346.0},
#   {'direction': 'UPWARD',
#    'end_date': '2017-04-21 00:00:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 23:30:00',
#    'type': 'aFRR',
#    'value': 0.0},
#   {'direction': 'DOWNWARD',
#    'end_date': '2017-04-21 00:00:00',
#    'price': '488.0',
#    'start_date': '2017-04-21 23:30:00',
#    'type': 'aFRR',
#    'value': 193.0}],
#  'end_date': '2017-04-21 23:30:00',
#  'resourcename': 'activated_offers',
#  'start_date': '2017-04-21 00:00:00'}
