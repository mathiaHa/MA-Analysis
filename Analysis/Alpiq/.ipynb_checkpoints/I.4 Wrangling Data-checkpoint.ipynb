# %%
import os
import sys
import types
import itertools
import json

import pydocumentdb.documents as documents
import pydocumentdb.document_client as document_client
import pydocumentdb.errors as errors
import pydocumentdb.http_constants as http_constants

import pandas as pd; pd.options.display.max_rows =300
import pandasql as sqldf
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np

import view.config as cfg
import view.storage as st
import view.normalization as norm
import view.analyze as ana

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from IPython.core.display import HTML
from IPython.display import display

# %%
HOST = cfg.settings.host
MASTER_KEY = cfg.settings.master_key
DATABASE_ID = cfg.settings.database_id
COLLECTION_ID = cfg.settings.collection_id
COLLECTION_ID ="causality1"

# %%
res_names = ["peak_daily_margins"]

# %%
res_names = ["procured_reserves", "accepted_offers", "insufficients_offers", "activated_offers", "peak_daily_margins"]

# %% [markdown]
# ### 1. Get Data From Cosmos

# %%
client = document_client.DocumentClient(HOST, {'masterKey': MASTER_KEY})

coll_link = st.GetCollectionLink(client, DATABASE_ID, COLLECTION_ID)
proc_id = "ReadResources"

options = { 'enableScriptLogging': True }
params = {
    "resources": res_names, 
    "start": "2016-02-18T00:00:00+02:00",
    "end": "2016-02-18T23:30:00+01:00",
    "options" : {
        "pageSize":-1
    }
}

dodocs = st.ExecuteProcedure( client, coll_link, proc_id, params, options )
# Out:
# None

# %% [markdown]
# ### 2. Concatenate Data

# %%
data = []

for key, value in dodocs.iteritems():
    df = pd.DataFrame(value)
    df["resource"] = key
    df["alert"] = "NORMAL"
    df["downgraded"] = "NORMAL"
    data.append(df)

data = norm.FindProbableFloat(data)
df = pd.concat(data, axis=0)
# Set date columns as normalized datetime columns
df[["start_date", "end_date"]]= df[["start_date", "end_date"]].astype(np.datetime64)
df = df[df.start_date < df.end_date]
# Out:
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\pandas\core\internals.py:3224: FutureWarning: Passing in 'datetime64' dtype with no frequency is deprecated and will raise in a future version. Please pass in 'datetime64[ns]' instead.
#   return self.apply('astype', dtype=dtype, **kwargs)

# %% [markdown]
# ### 3. Propagage peak_daily_margins and insufficients_offers

# %%
for index, row in df[df.resource == "insufficients_offers"].iterrows():
    if row.type == "DOWNGRADED":
        condition = np.logical_and(df.start_date >= row.start_date, df.start_date < row.end_date)
        df.loc[condition, "downgraded"] = row.nature
    elif row.type == "WARNING":
        condition = np.logical_and(df.start_date >= row.start_date, df.start_date < row.end_date)
        df.loc[condition, "alert"] = row.nature

indexs = []
df3 = pd.DataFrame([])
for index, row in df[df.resource == "peak_daily_margins"].iterrows():
    
    start = pd.date_range(start=row.start_date, end=row.end_date, freq='30T', closed='left')
    end = pd.date_range(start=row.start_date, end=row.end_date, freq='30T', closed='right')
    
    do = df[df.start_date == row.start_date]
    row.direction = do[do.resource == "accepted_offers"].direction.unique()[0]
    
    df2 = pd.concat([row]*len(start), ignore_index=True, axis=1).T
    
    df2.start_date = start
    df2.end_date = end
    
    df3 = df3.append(df2)
    indexs.append(index)

df = df.drop(df.index[[indexs]])
df = df.append(df3, ignore_index=True)

# %% [markdown]
# ### 4. Drop useles data

# %%
# Drop Rows
df = df[df.resource != "insufficients_offers"]

# %% [markdown]
# ### 5. Reshape dataframe

# %%
valueList = ["available_value","price", "required_value", "value"]
print valueList
# Set Categorical columns
#categoryList = list(df.select_dtypes(include=["object"]).columns)
#df[categoryList] = df[categoryList].apply(lambda x: x.astype('category'), axis=1)

divider = getattr(cfg.groups, "balancing_capacity")
NumberTypes = (types.IntType, types.LongType, types.FloatType, types.ComplexType)
if not valueList ==[] :
    table_df = pd.pivot_table(
                df,
                values=valueList,
                index=['start_date','end_date','resource','type','direction','alert','downgraded'],
                aggfunc= 'first')
    
    # Go from multi columns to cube
    level = 7
    table_df = table_df.stack(0).reset_index(level)
    table_df = table_df.rename(index=str, columns={"level_"+str(level): "value_type"})
    
    # Set date columns as normalized datetime columns
    table_df = table_df.reset_index()
    table_df[["start_date", "end_date"]]= table_df[["start_date", "end_date"]].astype(np.datetime64)
    
    
    # Set multi index dataframe
    table_df = table_df.set_index(['start_date','end_date','resource','type','direction','alert','downgraded',"value_type"])
    table_df = table_df.rename(index=str, columns={0:"value"})
# Out:
# ['available_value', 'price', 'required_value', 'value']

# %%
data_query = """
    select 
        t.value, 
        t.start_date
    from 
        table_df as t
    where 
        t.value_type = '{value_type}' and
        t.resource = '{resource}';
"""

print data_query.format(value_type="required_value", resource = "peak_daily_margins")
# Out:
#     select
#         t.value,
#         t.start_date
#     from
#         table_df as t
#     where
#         t.value_type = 'required_value' and
#         t.resource = 'peak_daily_margins';

# %%
index_query = """
    select
        table_df.start_date,
        table_df.end_date,
        table_df.resource,
        table_df.type,
        table_df.direction,
        table_df.alert,
        table_df.downgraded,
        table_df.value_type
    from 
        table_df
"""

q2 = """
    select
        a.*,
        r.value as required_value
    from 
        (select * from table_df where table_df.resource = 'peak_daily_margins' and table_df.value_type = 'available_value') as a
    inner join
        (select * from table_df where table_df.resource = 'peak_daily_margins' and table_df.value_type = 'required_value') as r
            on a.start_date = r.start_date
    where
        a.downgraded = 'BALANCE_SUPPLY_DEMAND';
"""

print q2
sqldf(q2, locals()).plot(figsize=(40,20))
plt.show()
# Out:
#     select
#         a.*,
#         r.value as required_value
#     from
#         (select * from table_df where table_df.resource = 'peak_daily_margins' and table_df.value_type = 'available_value') as a
#     inner join
#         (select * from table_df where table_df.resource = 'peak_daily_margins' and table_df.value_type = 'required_value') as r
#             on a.start_date = r.start_date
#     where
#         a.downgraded = 'BALANCE_SUPPLY_DEMAND';

# %%
masked = table.xs(slice('2016-02-18 05:00:00','2016-02-18 05:00:00'), level="start_date", drop_level = False)
ins = ana.MultipleFilter(table, ["mFRR"])
table.xs(("insufficients_offers"), level=("resource"), drop_level=False)
masked
# Out:
#                                                                                                     value
# start_date          end_date            resource             type       value_type
# 2016-02-18 05:00:00 2016-02-18 05:30:00 accepted_offers      AFRR       direction                 UP_DOWN
#                                                                         value                         905
#                                                              FCR        direction                 UP_DOWN
#                                                                         value                         876
#                                         activated_offers     RR         direction                  UPWARD
#                                                                         price                        90.3
#                                                                         value                        1150
#                                         procured_reserves    AFRR       direction                 UP_DOWN
#                                                                         price                        9.18
#                                                                         value                         900
#                                                              FCR        direction                 UP_DOWN
#                                                                         price                        9.18
#                                                                         value                         572
#                                                              MFRR       direction                  UPWARD
#                                                                         price                        2.99
#                                                                         value                        1040
#                     2016-02-18 13:00:00 insufficients_offers DOWNGRADED direction                  UPWARD
#                                                                         nature      BALANCE_SUPPLY_DEMAND
