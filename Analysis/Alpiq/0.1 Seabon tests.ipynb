# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Generate a random univariate dataset
d = rs.normal(size=100)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a historgram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()
plt.show()

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")
print tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
grid = sns.FacetGrid(tips, row='size', col='sex', xlim=(4, -2), hue='smoker',
                     sharey=False, size=1.5, aspect = 1.7, margin_titles=False)
grid.map(sns.distplot, 'tip',bins=np.arange(1,10, 0.3), 
                      hist_kws=dict(alpha=0.1))
grid.map(sns.plt.axvline, x=0, c='grey', lw=1)
grid.set(yticks=[])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-665622ecc3f5> in <module>()
#       2                      sharey=False, size=1.5, aspect = 1.7, margin_titles=False)
#       3 grid.map(sns.distplot, 'tip',bins=np.arange(1,10, 0.3),
# ----> 4                       hist_kws=dict(alpha=0.1))
#       5 grid.map(sns.plt.axvline, x=0, c='grey', lw=1)
#       6 grid.set(yticks=[])
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\seaborn\axisgrid.pyc in map(self, func, *args, **kwargs)
#     729
#     730             # Draw the plot
# --> 731             self._facet_plot(func, ax, plot_args, kwargs)
#     732
#     733         # Finalize the annotations and layout
#
# C:\Users\hauretouze_m\AppData\Local\conda\conda\envs\ipykernel_py2\lib\site-packages\seaborn\axisgrid.pyc in _facet_plot(self, func, ax, plot_args, plot_kwargs)
# ...
